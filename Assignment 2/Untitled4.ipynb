# %% [markdown]
# # Introduction

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Login

# %%
token = "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"
# !huggingface-cli login --token $token
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# The token `mistral v0.2+v0.3` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `mistral v0.2+v0.3`

# %% [markdown]
# ### Data

# %%
import requests
import os
import pandas as pd

# Create directory structure if it doesn't exist
base_dir = 'Assignment 2/data'
if not os.path.exists(base_dir):
    os.makedirs(base_dir)

# Updated URLs for the raw files on GitHub
urls = {
    'test': 'https://raw.githubusercontent.com/lt-nlp-lab-unibo/nlp-course-material/main/2024-2025/Assignment%202/data/a2_test.csv',
    'demos': 'https://raw.githubusercontent.com/lt-nlp-lab-unibo/nlp-course-material/main/2024-2025/Assignment%202/data/demonstrations.csv'
}

# Download files
for name, url in urls.items():
    response = requests.get(url)
    if response.status_code == 200:
        filepath = os.path.join(base_dir, f'{name}.csv')
        with open(filepath, 'wb') as f:
            f.write(response.content)
        print(f"Successfully downloaded {filepath}")
    else:
        print(f"Failed to download {name} dataset. Status code: {response.status_code}")
        print(f"URL attempted: {url}")

# Verify files exist before loading
if os.path.exists(os.path.join(base_dir, 'test.csv')) and os.path.exists(os.path.join(base_dir, 'demos.csv')):
    # Load the datasets using pandas

    test_df = pd.read_csv(os.path.join(base_dir, 'test.csv'))
    demos_df = pd.read_csv(os.path.join(base_dir, 'demos.csv'))

    # Display first few rows of test dataset
    print("\nFirst few rows of test dataset:")
    print(test_df.head())
    # Display basic information about both datasets
    print("\nTest dataset info:")
    print(test_df.info())
    print("\nDemonstrations dataset info:")
    print(demos_df.info())
else:
    print("\nFiles were not downloaded successfully. Please check the repository URLs.")
# Out:
# Successfully downloaded Assignment 2/data/test.csv
# Successfully downloaded Assignment 2/data/demos.csv
#
# First few rows of test dataset:
#                   rewire_id  \
# 0  sexism2022_english-17133
# 1  sexism2022_english-14197
# 2   sexism2022_english-3018
# 3   sexism2022_english-5301
# 4  sexism2022_english-17796
#
#                                                 text label_sexist
# 0  The boys must be gaming because there goes the...   not sexist
# 1  Look at those eyes. Either someone unexpectedl...       sexist
# 2                  Old man mogs everyone in this sub   not sexist
# 3  Excellent, I was just looking at another post ...   not sexist
# 4  So you run back to daddy whenever you need hel...       sexist
#
# Test dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rewire_id     300 non-null    object
#  1   text          300 non-null    object
#  2   label_sexist  300 non-null    object
# dtypes: object(3)
# memory usage: 7.2+ KB
# None
#
# Demonstrations dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rewire_id     1000 non-null   object
#  1   text          1000 non-null   object
#  2   label_sexist  1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB
# None

# %% [markdown]
# # [Task 1]: Model(s) setup

# %%
# system packages
from pathlib import Path
import shutil
import urllib
import tarfile
import sys

# data and numerical management packages
import pandas as pd
import numpy as np

# useful during debugging (progress bars)
from tqdm import tqdm
# !pip install transformers
# !pip install datasets
# !pip install accelerate -U
# !pip install evaluate
# !pip install bitsandbytes
import torch
torch.cuda.is_available()
# !nvidia-smi
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.5.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 28.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.12.14)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.11.11)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0
# Thu Jan  9 20:53:43 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from transformers import BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# %% [markdown]
# ## Mistral-7B-v0.3

# %%
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

mistral_modelcard = "mistralai/Mistral-7B-Instruct-v0.3" # choose mistral model
mistral_tokenizer = AutoTokenizer.from_pretrained(mistral_modelcard) # autotokenizer
mistral_tokenizer.pad_token = mistral_tokenizer.eos_token # Set the padding token to be the same as the end-of-sequence token


# Define special tokens that indicate the end of generation
mistral_terminators = [
    mistral_tokenizer.eos_token_id,
    mistral_tokenizer.convert_tokens_to_ids("<|eot_id|>")
]



mistral_model = AutoModelForCausalLM.from_pretrained(
    mistral_modelcard,
    return_dict=True,
    quantization_config=bnb_config,
    device_map='auto'
)

# Clear CUDA cache
torch.cuda.empty_cache()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# ## Phi 3 mini 4k instruct

# %%
phi3_modelcard = "microsoft/Phi-3-mini-4k-instruct" # choose phi3 model
phi3_tokenizer = AutoTokenizer.from_pretrained(phi3_modelcard, trust_remote_code=True)
# Define special tokens that indicate the end of generation
phi3_terminators = [
    phi3_tokenizer.eos_token_id,
    phi3_tokenizer.convert_tokens_to_ids("<|eot_id|>")
]
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig


phi3_model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    trust_remote_code=True,
    device_map="auto",
    quantization_config=bnb_config,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True
)

# Clear CUDA cache
torch.cuda.empty_cache()
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]

# %% [markdown]
# ## Qwen 2 7B Instruct

# %%
model_card = "Qwen/Qwen2-7B-Instruct"
# Configure memory and device mapping
max_memory = {
    0: "13GB",      # Reserve most T4 GPU memory
    "cpu": "25GB"   # Allow CPU offloading
}

# Load tokenizer
qwen_tokenizer = AutoTokenizer.from_pretrained(model_card)

# Load model with optimized settings
qwen_model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen2-7B-Instruct",
    quantization_config=bnb_config,
    device_map="balanced",  #  Balanced memory distribution
    max_memory=max_memory,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    offload_folder="offload"  # Enable disk offloading if needed
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]

# %% [markdown]
# # [Task 2] Prompt setup

# %%
prompt = [
    {
        'role': 'system',
        'content': 'You are an annotator for sexism detection.'
    },
    {
        'role': 'user',
        'content': """Your task is to classify input text as containing sexism or not. Respond only YES or NO.

        TEXT:
        {text}

        ANSWER:
        """
    }
]

# %%
def prepare_prompts(texts, prompt_template, tokenizer):
    """
    This function formats input text samples into instruction prompts.
    """
    formatted_prompts = []

    for text in texts:
        # Create a deep copy of the template to avoid modifying the original
        current_prompt = [
            prompt_template[0].copy(),
            prompt_template[1].copy()
        ]

        # Format the user content by replacing the {text} placeholder
        current_prompt[1]['content'] = current_prompt[1]['content'].format(text=text)

        # Convert the prompt list into a chat format string
        chat_text = f"{current_prompt[0]['content']}\n\n{current_prompt[1]['content']}"

        # Tokenize the formatted prompt
        encoded_prompt = tokenizer(
            chat_text,
            padding=True,
            truncation=True,
            return_tensors="pt"
        )

        formatted_prompts.append(encoded_prompt)

    return formatted_prompts

# %% [markdown]
# # [Task 3] Inference

# %%
import json
from datetime import datetime
import os

def save_model_results(results, model_name, shot_count=None):
    """
    Save model results to a JSON file

    Args:
        results: Dictionary containing model results
        model_name: Name of the model
        shot_count: Number of shots (None for zero-shot)
    """
    # Create results directory if it doesn't exist
    os.makedirs('model_results', exist_ok=True)

    # Format timestamp
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')

    # Create filename based on whether it's zero-shot or few-shot
    if shot_count is None:
        filename = f"model_results/{model_name}_zero_shot_{timestamp}.json"
    else:
        filename = f"model_results/{model_name}_{shot_count}_shot_{timestamp}.json"

    # Convert results to serializable format
    serializable_results = []
    for item in results:
        serializable_item = {
            'sample_idx': int(item['sample_idx']),
            'text': str(item['text']),
            'true_label': str(item['true_label']),
            'predicted_label': str(item['predicted_label']),
            'raw_response': str(item['raw_response']),
            'correct': bool(item['correct'])
        }
        serializable_results.append(serializable_item)

    # Save to file
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump({
            'model_name': model_name,
            'shot_count': shot_count,
            'timestamp': timestamp,
            'results': serializable_results
        }, f, indent=4, ensure_ascii=False)

    print(f"Results saved to {filename}")

def load_model_results(filename):
    """
    Load model results from a JSON file

    Args:
        filename: Path to the JSON file

    Returns:
        Dictionary containing the loaded results
    """
    with open(filename, 'r', encoding='utf-8') as f:
        return json.load(f)

# Example of loading results back
def load_all_results(directory="model_results"):
    """
    Load all saved results from the model_results directory

    Returns:
        Dictionary containing all loaded results organized by model and shot count
    """
    all_results = {
        'zero_shot': {},
        'few_shot': {}
    }

    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            filepath = os.path.join(directory, filename)
            data = load_model_results(filepath)
            model_name = data['model_name']
            shot_count = data['shot_count']

            if shot_count is None:
                all_results['zero_shot'][model_name] = data['results']
            else:
                if model_name not in all_results['few_shot']:
                    all_results['few_shot'][model_name] = {}
                all_results['few_shot'][model_name][shot_count] = data['results']

    return all_results

# %%
def generate_responses(model, prompt_examples):
    """
    This function implements the inference loop for a LLM model.
    """
    responses = []
    device = next(model.parameters()).device

    # Extract model name and tokenizer with detailed debugging
    model_vars = [name for name, obj in globals().items() if obj is model]
    if not model_vars:
        raise ValueError("Could not find model variable name in global scope")

    #print("\nDebugging tokenizer lookup:")
    #print(f"1. Found model object: {model}")
    #print(f"2. Found model variable name(s): {model_vars}")
    model_name = model_vars[0].replace('_model', '')
    #print(f"3. Extracted model name: {model_name}")
    tokenizer_name = f"{model_name}_tokenizer"
    #print(f"4. Looking for tokenizer with name: {tokenizer_name}")
    #print(f"5. Available global variables: {[name for name in globals().keys() if 'tokenizer' in name.lower()]}")

    try:
        tokenizer = globals()[tokenizer_name]
        #print(f"6. Successfully found tokenizer: {tokenizer}")
    except KeyError:
        raise KeyError(f"Could not find tokenizer '{tokenizer_name}' in globals. Available tokenizers: {[name for name in globals().keys() if 'tokenizer' in name.lower()]}")

    # Rest of the function remains the same
    yes_tokens = tokenizer(" YES", add_special_tokens=False)['input_ids']
    no_tokens = tokenizer(" NO", add_special_tokens=False)['input_ids']

    with torch.no_grad():
        for encoded_prompt in prompt_examples:
            input_ids = encoded_prompt['input_ids'].to(device)
            attention_mask = encoded_prompt['attention_mask'].to(device)

            outputs = model.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_new_tokens=3,
                do_sample=False,
                num_beams=1,
                pad_token_id=model.config.eos_token_id,
                eos_token_id=tokenizer.eos_token_id,
            )

            new_tokens = outputs[0][input_ids.shape[1]:]
            decoded_output = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()

            if 'YES' in decoded_output.upper():
                decoded_output = 'YES'
            elif 'NO' in decoded_output.upper():
                decoded_output = 'NO'
            else:
                logits = model(input_ids, attention_mask=attention_mask).logits
                next_token_logits = logits[0, -1]
                yes_score = sum(next_token_logits[tid] for tid in yes_tokens)
                no_score = sum(next_token_logits[tid] for tid in no_tokens)
                decoded_output = 'YES' if yes_score > no_score else 'NO'

            responses.append(decoded_output)
            torch.cuda.empty_cache()

    return responses

# %%
def process_response(response):
    """
    This function processes model responses into binary labels.

    Inputs:
      response: the raw text response from the model

    Outputs:
      binary label (sexist/not sexist)
    """
    # Convert response to lowercase for case-insensitive matching
    response = response.lower().strip()
    #print(f"response: {response}")
    # Check for "yes" indicating sexist content
    if "yes" in response:
        return 1
    # Check for "no" indicating not sexist content
    elif "no" in response:
        return 0
    else:
        # invalid repsonse
        return None

# %%
import json
def test_random_samples_with_timing(model, tokenizer, test_df, prompt_template, num_samples=10):
    results = []
    device = next(model.parameters()).device
    tokenizer.pad_token = tokenizer.eos_token

    # Get equal number of samples from both classes
    samples_per_class = num_samples // 2

    # Get indices for both classes
    sexist_indices = test_df[test_df['label_sexist'] == 'sexist'].index
    not_sexist_indices = test_df[test_df['label_sexist'] == 'not sexist'].index

    # Randomly sample indices from both classes
    selected_sexist = random.sample(list(sexist_indices), min(samples_per_class, len(sexist_indices)))
    selected_not_sexist = random.sample(list(not_sexist_indices), min(samples_per_class, len(not_sexist_indices)))

    # Combine and shuffle the selected indices
    selected_indices = selected_sexist + selected_not_sexist
    random.shuffle(selected_indices)

    start_time = time.time()

    # Loop over the selected samples
    for i, idx in enumerate(selected_indices):
        # Get the sample text and true label
        sample_text = test_df.iloc[idx]['text']
        true_label = test_df.iloc[idx]['label_sexist']

        print(f"\nSample {i+1}/{len(selected_indices)}:")
        print(f"Selected text: {sample_text}")
        print(f"True label: {true_label}")

        # Format the prompt and generate response
        formatted_prompts = prepare_prompts([sample_text], prompt_template, tokenizer)

        # Print the formatted prompt
        input_ids = formatted_prompts[0]['input_ids'][0]
        formatted_text = tokenizer.decode(input_ids)

        # Move tensors to device
        for j in range(len(formatted_prompts)):
            formatted_prompts[j] = {k: v.to(device) for k, v in formatted_prompts[j].items()}

        responses = generate_responses(model, formatted_prompts)
        binary_label = process_response(responses[0])
        predicted_label = "sexist" if binary_label == 1 else "not sexist"

        print(f"Predicted label: {predicted_label}")
        print("-" * 80)

        # Save result
        result = {
            'sample_idx': idx,
            'text': sample_text,
            'true_label': true_label,
            'predicted_label': predicted_label,
            'raw_response': responses[0],
            'correct': predicted_label == true_label
        }
        results.append(result)

    total_time = time.time() - start_time

    # Calculate summary statistics
    correct_predictions = sum(result['correct'] for result in results)
    accuracy = correct_predictions / len(results)

    sexist_correct = sum(1 for r in results
                        if r['true_label'] == 'sexist' and r['correct'])
    not_sexist_correct = sum(1 for r in results
                            if r['true_label'] == 'not sexist' and r['correct'])

    sexist_total = sum(1 for r in results if r['true_label'] == 'sexist')
    not_sexist_total = sum(1 for r in results if r['true_label'] == 'not sexist')

    print("\nResults Summary:")
    print(f"Overall Accuracy: {accuracy:.2%}")
    print(f"Sexist Accuracy: {sexist_correct/sexist_total:.2%} ({sexist_correct}/{sexist_total})")
    print(f"Not Sexist Accuracy: {not_sexist_correct/not_sexist_total:.2%} ({not_sexist_correct}/{not_sexist_total})")

    # Add timestamp to results metadata
    test_metadata = {
        'timestamp': time.strftime('%Y-%m-%d_%H-%M-%S'),
        'model': model_card,
        'num_samples': num_samples,
        'overall_accuracy': float(accuracy),  # Convert to float for JSON serialization
        'sexist_accuracy': float(sexist_correct/sexist_total),
        'not_sexist_accuracy': float(not_sexist_correct/not_sexist_total),
        'execution_time': float(total_time),
        'avg_time_per_sample': float(total_time/len(results))
    }

    # Create results directory if it doesn't exist
    os.makedirs('results', exist_ok=True)

    # Save detailed results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv(f'results/test_results_{test_metadata["timestamp"]}.csv', index=False)

    # Save metadata and summary to JSON
    with open(f'results/test_metadata_{test_metadata["timestamp"]}.json', 'w') as f:
        json.dump(test_metadata, f, indent=4)

    print(f"\nResults saved to:")
    print(f"- results/test_results_{test_metadata['timestamp']}.csv")
    print(f"- results/test_metadata_{test_metadata['timestamp']}.json")

    return results

# %% [markdown]
# ## Run with Mistral

# %%
import time, random
from datetime import timedelta

# Run test on n samples
tokenizer = mistral_tokenizer
start_time = time.time()
mistral_results = test_random_samples_with_timing(mistral_model, tokenizer, test_df, prompt, num_samples=300)
total_time = time.time() - start_time
print(f"\nTotal execution time: {str(timedelta(seconds=total_time))}")
print(f"Average time per sample: {str(timedelta(seconds=total_time/100))}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Sample 1/300:
# Selected text: Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 2/300:
# Selected text: No where near as bad as the average wife who not just prey's on the husband via divorce court, but destroys children's lives while she's at it.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 3/300:
# Selected text: Hillary Clinton fucking delivered a damn BlackHawk helicopter to ISIS Leader Baghdadi as a GIFT!!!! How sweet of her!!! The Bitch!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 4/300:
# Selected text: Twitter hasn't suspended the account? They must really hate guys and whites lol
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 5/300:
# Selected text: oh no! So they are saying if I send my daught to college she might.... put on a hat? OH THE HUMANITY!!!!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 6/300:
# Selected text: Giving women all your money is good personality.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 7/300:
# Selected text: I hate when I see a nigga come /this close 👌/ to saying women need to stick to our roles, but then adds just a pinch of feminist bullshit in a cucked attempt to not look "sexist".
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 8/300:
# Selected text: You’re overthinking it completely. Whether you sit next to her or not next time you see her talk to her and ask her out...
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 9/300:
# Selected text: #EmpressMichelle just needs to pack her shit, #stfu and move to Venezuela. Thank you to all the #Libtards who gave us these two pieces of shit [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 10/300:
# Selected text: Damn right. Contraceptives and carpet bombs. We made 'em, we can take 'em out. It is our right as the reason why they exist in the first place, we are their gods. We can giveth and we can taketh away. / Too far ?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 11/300:
# Selected text: Look at those eyes. Either someone unexpectedly just fisted her up the dumper, or that bitch is certifiably a nutburger.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 12/300:
# Selected text: If your a simp women will destroy you. If you tell them to fuck off they are MUCH more likely to leave you alone. Choose.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 13/300:
# Selected text: Like the "stunning and brave" woman that """stopped the police""" by showing her pussy. As if police was there only for her...
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 14/300:
# Selected text: Damn Global Warming! [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 15/300:
# Selected text: First. Black Democrats upset that Black unemployment is down. Now. Feminists upset with good looking women so they get Grid girls fired. Next. LGBTQ community wants AIDS to come back.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 16/300:
# Selected text: I had one punch me in the stomach. I return the favor back. First time I ever punch a lady(monster)
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 17/300:
# Selected text: Why the fuck would you go for crazy bitches?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 18/300:
# Selected text: Yeah man I had a plate who did everything for me, untill she started saying I was an enigma and some people talked to me about how I was an emotionless robot with her. I opened up abit and not even a week later she lost interest.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 19/300:
# Selected text: While I agree that its a clear sign of immaturity, women still speak this way into their late 20's. The more spoiled they are the longer it lasts.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 20/300:
# Selected text: How long will it take a woman to mentally move on from the situation? Cause they're fond of bringing up shit from before my ancestors
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 21/300:
# Selected text: Overheard at Star Wars RPG Night: “I cut open the door with my lightsaber and roll through the hole in one move. Best use of a Triumph EVER!” Me: “I don’t know. I once saw a guy pick up 3 hot girls in a TR-3.”
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 22/300:
# Selected text: This is something you can either do naturally or you can't do at all. If you can't do it naturally don't even try because you'll come across as an arrogant shit and people will hate you. Find a different way to be charming. Just be yourself.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 23/300:
# Selected text: Intolerant feminist attacks “Doctor Who” British TV show for not being transgender or black enough - Tyranny News [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 24/300:
# Selected text: No. First my mom became a whore after dad left and was a huge bitch! Oh god, why won't she love me?!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 25/300:
# Selected text: The lawyer chick will shoot down the McDonald's guy, every time, no matter how he looks. That's just the world that we live in. Agree to disagree, I suppose.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 26/300:
# Selected text: Hhaaha I fucking hate women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 27/300:
# Selected text: No women love chads And tyrones with the bbc Women love black men
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 28/300:
# Selected text: My state? I'm not Jewish. They literally won't stop until they destroy Israel and kill every Jewish person. Have you even read the Qur'an? It was created to give them a sanctuary if Nazi Germany type countries ever rose up again.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 29/300:
# Selected text: Porn is always true
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 30/300:
# Selected text: CRAZY BIMBO IS BACK! White Uncle Tom: Rachel Dolezal says she's "Trans-Black." Ugh, this dumb bitch! I thought society was through with her! [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 31/300:
# Selected text: Are your chromosomes XX? If so, you're 100% female.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 32/300:
# Selected text: Freakish lesbian, Ellen Degenerate, has been burned out of her home in California [URL] The wildfires are cleansing fires :)
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 33/300:
# Selected text: I can give lots of info on this. Dm if you have questions. Yes youll meet lots of women doing this. However it has not made me any more successful with women if Im being honest.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 34/300:
# Selected text: Folks [USER] is what having a small cock looks like Poor little [USER]. Nobody likes him, he has a small pencil dick, he has problems meeting women, and he can't get his testosterone patch dosage correct!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 35/300:
# Selected text: Are they going to record all Anti-White hate crimes? Are they going to record every Rape of young White girls by Moslems? Are they going to record every murder of Whites, by Black/Moslems?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 36/300:
# Selected text: [USER] i can't stand idiots running our nation overlooking the true domestic enemies against our constitution and our nation making them enemies to our own nation.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 37/300:
# Selected text: This man deserves to be hailed a hero he looked in the eyes of an ugly four eyed hijab and gave hwr the only respect she deserves blood and death
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 38/300:
# Selected text: [USER] Exactly... which is why she loved Obama. Well sorry old hag... your time is done. The world is waking up to the truth.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 39/300:
# Selected text: Get packing you miserable freeze-dried old Kike cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 40/300:
# Selected text: Truefemcels is troll idk about fa, inb4 bbw whaling starts ranting about fa having truecel women
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 41/300:
# Selected text: I have an alt account pretending to be a woman. My mission is making FDS females as toxic as possible I've gotten thousands of up votes while posting grade A bitch shit
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 42/300:
# Selected text: \>woman here Opinion discarded.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 43/300:
# Selected text: Banging a white girl like her [she's a felon.. ]([URL] I always love rogue white chicks. Her smile is hot.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 44/300:
# Selected text: Like a typical woman, always waiting for the men to fix a problem instead of actually working on anything. Golf clap.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 45/300:
# Selected text: 3rd World Shitholer party of criminals. Send Cortez back to her 3rd world shithole & all her supporters.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 46/300:
# Selected text: what have you tried already? I like to point out that nobody blinks when a smaller man starts shit with a larger man and gets his ass beat, men and women are equal right?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 47/300:
# Selected text: Holy fuck is this for real
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 48/300:
# Selected text: It hasn't for many because this greedy bastard had to try and get it all for himself.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 49/300:
# Selected text: Guys a retard , who wants attention
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 50/300:
# Selected text: They crap on their credibility each & every day just waiting On Patriotic Americans to die of old age .. ..or a well~calculated drone strike if HRC could have her way!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 51/300:
# Selected text: She's not crying. She's probably texting her friends complaining about the Fags at the gym.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 52/300:
# Selected text: Man already jailed to be arraigned in Tucson girls' slayings [URL] #ToxicDiversity
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 53/300:
# Selected text: You know you've achieved peak feminism when formerly safe women are being gang raped and murdered by Africans who shouldn't be in the country and the police can't do anything to stop it.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 54/300:
# Selected text: Yes, let's all be LECTURED by a Jack-ass like this Jimbo Bono's Bud in Red #BoycottedOscars #BoycottHollywood
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 55/300:
# Selected text: having sex at 15 is not ok! Let alone a gangbang...damn.... And people like u are trying so desperately to normalize it...at 15....they are just kids man!!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 56/300:
# Selected text: Can you imagine just how incredibly butthurt the democrats would be if Trump does so well that the first female president ends up his daughter Ivanka. They try to make a witch the first female POTUS, and instead we get an angel lol. #Trump #MAGA
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 57/300:
# Selected text: Chelsea Clinton leaned over to her husband and said something about Melania. Not sure what she said, but I guarantee it was classless. #PresidentialDebates
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 58/300:
# Selected text: Your wife could leave her phone at the office Women can’t be parted with Instagram for two minutes while taking shit mate, what are you talking about even?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 59/300:
# Selected text: She's getting ready to ghost you, pull back a little pursing her and wait for her to reach out to you. She is probably feeling a little crowded by your attention. In the meantime hit up other girls
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 60/300:
# Selected text: I hope the DOJ goes after EVERY DEMOCRAT for ANY tax, bank, campaign fraud they can find. ANY of it! EVEN IF from 10 years ago. These political prosecutions will only end when the dems cry "Uncle!"
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 61/300:
# Selected text: As an Eagle Scout, I'm less than pleased with all of this. If women wanted to destroy the BSA, they've done it.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 62/300:
# Selected text: Tell that to Weev you lying shitskin son of a bitch.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 63/300:
# Selected text: so they confirm being a women means being a hole. sexist pig vice! REEEEEEEE
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 64/300:
# Selected text: Don’t hate women I just understand the price that is paid being with them (not sex) and it’s not worth it...AT ALL.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 65/300:
# Selected text: George Deriziotis George Deriziotis 3 hours ago And she represents the democratic party? Please, don't replace her!!! She's the PERFECT representative for the democratic party!!!﻿
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 66/300:
# Selected text: It's a sickening thought to realize roughly half our nation's population think we're their enemy because we genuinely support our Constitution. They support Social Justice and Gender Neutrality.... #WeCanNoLongerCoexistInPeace
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 67/300:
# Selected text: What's the going timeframe onto getting on GAB nowadays??? I'm trying to recruit hardcore since twat is going crazy with censorship.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 68/300:
# Selected text: Passes IHRA anti-semitism laws to shut the British people's mouths and puts pedoes on the fast track for adoption. She can not be anymore than 2 steps away from her boss, SATAN. What a cunt
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 69/300:
# Selected text: this just this! enjoy it. what a bozo she is..... #Freaky Frederica
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 70/300:
# Selected text: The queen is not representing herself and a direct descendant of Muhammad & high up in the Catholic church of the illuminati ... so are you surprised about this abuse of children?
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 71/300:
# Selected text: Now we need a woman come out & accuse Hillary of sexual abuse. [USER]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 72/300:
# Selected text: This whore deserves to be shot to death. Women have no control. I hope someone shoots her to death in jail before she goes to trial. UK has the most fucked up feminist society.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 73/300:
# Selected text: Not if she wants it. Only prudish women hate dirty talk from attractive men from the getgo.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 74/300:
# Selected text: Meh- women in 2018 are pure cancer. Don't even touch them with a 12 foot barge pole.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 75/300:
# Selected text: Full on crotch grab from Biden. Even the baby's mom isn't holding him that way.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 76/300:
# Selected text: I hate her.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 77/300:
# Selected text: There was an experiment where the scientists were introducing the value of the money to monkeys or chimpanzees. Just little shiny discs they could trade for food and things. It didn't take the females long to start selling sex. Well, there you go.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 78/300:
# Selected text: Depends on the girl, on both sides of this. Average girl gives an average blowjob, paid or not. And you can get high end escorts, or just more willing girls where it’s all on the table.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 79/300:
# Selected text: "Where on Earth do you get all your ideas from for your sick jokes?" asked my wife. Then she fell out of her wheelchair.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 80/300:
# Selected text: Hillary should also have her clearance revoked.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 81/300:
# Selected text: Damn now i have an idea. Making a fake Chad account and getting multiple roasties emotionally invested and then breaking their hearts, if they even have one. I shall find out for SCIENCE.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 82/300:
# Selected text: Damn...this pisses me off to no end! These mother fuckers need to start gracing the halls of maximum security federal facilities!
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 83/300:
# Selected text: new male successes will arise out of the ashes of lost ones like comic culture, pc gaming, herioc fantasy, boyscouts etc. may they forever remained scorned and ridiculed by women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 84/300:
# Selected text: Hahaha, what a cuckold. I would've just ghosted her. "I will not tell her what to do" YOU ARE IN A RELATIONSHIP WITH HER, ITS YOUR DUTY TO TELL HER WHAT TO DO. Cuckold motherfucker. Now it's too late, dump the bitch.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 85/300:
# Selected text: Well said. Single mothers would not get this point.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 86/300:
# Selected text: i expect to have boomers dissing national socialists right up until the communists shoot them all.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 87/300:
# Selected text: As if reading your BS would make me an intellectual. Women are more than willing to date damaged men as long as the guy is hot. They don't care about "work", they care about looks. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 88/300:
# Selected text: It stops white women from being hit (or worse) by niggers and thats as right as it gets.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 89/300:
# Selected text: GL convincing the idiot masses ......Black pastors see Trump bringing 'new hope' -- but still need to convince their flocks .....[URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 90/300:
# Selected text: You have no idea what you are talking about. Just another pussy making excuses for the world you're NOT fixing.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 91/300:
# Selected text: The moment my mom divorced my dad and went riding the cock carousel I knew I’d never date again. Seven years later I’ve held up. Been a great 7 years.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 92/300:
# Selected text: Excellent, I was just looking at another post where the female fvcked men to get grades, why support that, or even risk exposing ourselves to that type of fraudulent behavior.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 93/300:
# Selected text: Coffee, drink, walk in the park. That way if she's retarded you only wasted 20 mins of your life.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 94/300:
# Selected text: #Politics #GabFam #MAGA #Australia As #MSM develops a case of total silence while covering womens virtue signaling BS. Must've been the vagina hats rather than the FGM and child RAPES [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 95/300:
# Selected text: It will not stop until women are hurt enough by genital mutilation to decide it is a bad thing. Only then can we move to ban it for boys.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 96/300:
# Selected text: Pretty soon, looking at a woman is "eye rape". All men should move to Mars and leave this stinking Earth to women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 97/300:
# Selected text: It's part of the gynocentric society's effort to abolish all standards for women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 98/300:
# Selected text: Don't think that using the word "feminine" wasn't strategic, Mo. It was. And I couldn't agree more with everything else you wrote. They attempt to bring the rest of us down to their level. Not gonna happen ... Lol, men are a gift from God.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 99/300:
# Selected text: Well shit, you got me convinced. Where do I sign up to die in the race war, so that white women could fuck niggers without judgement?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 100/300:
# Selected text: Let’s hope her goal never materializes
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 101/300:
# Selected text: I'd be shocked if it ever worked, usually these thots are getting stretched on the side, and after Leafyishere did the content nuke on her, the tier 3 subs lost it. She has a boyfriend is now etched in their collective memories
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 102/300:
# Selected text: courage precludes the wise and strong from prostrating to his base emotions. let the woman freak out. were cooler under pressure, so lets be cool under pressure. let the women attack us physically, were stronger. being punched by a woman is a joke.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 103/300:
# Selected text: You say you're a MGTOW, why in the hell did you agree to this? She made her damn bed. Bet your ass she would have never done the same for you if you were in her situation.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 104/300:
# Selected text: I don't know if it would make it past the House but we can try to get a law passed saying that you can't turn your kid into a God damn fucking faggot ass drag queen or else you will spend some time in Federal prison getting boned up the ass.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 105/300:
# Selected text: Not all Blacks are complete NIGGERS like this whore The Pure POS Nigger bitch gives others a bad name fucking cunt Should investigate where she worked and deaths
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 106/300:
# Selected text: Hit her with a club on the back of the head and carry her back to your cave oonga boonga style
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 107/300:
# Selected text: Top kek. Disgusting old cripple resenting Chad for not wanting to fuck her roast beef cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 108/300:
# Selected text: Thats because all women are different, but all female nature is the same.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 109/300:
# Selected text: I'm thinking of starting a kickstarter or something to deprogram her with a scientific Psyops campaign so we don't have to endure her debased shenanigans anymore. I'll take a $million bounty if we turn her into a legit evangelical.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 110/300:
# Selected text: no, it's just not true shared environment has basically no effect on adult iq the data is clear iq is genetic just don't starve your kid or beat them after that it's genes and chance
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 111/300:
# Selected text: All women are children
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 112/300:
# Selected text: yeah but things are different now. tradcons are part of the problem. when the muslims take over, im gonna learn arabic and im gonna have me a harem. gotta admit muslims keep their women in check
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 113/300:
# Selected text: Trump extortionist Stormy Daniels to facilitate cryptocurrency payments on her website for porn content - [URL] #news #finance #bitcoin #stormydaniels
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 114/300:
# Selected text: Out of boredom I decided to read quite a few of the posts from cheeky monkey. My wife and I can't decide whether it's 1. A teenage girl or 2. Just a cunt I know it's possible to be both but I'm guessing it's 1 and my wife says 2.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 115/300:
# Selected text: Even us girls did this with or without our brothers. I miss those days when we loved earning money. The pride we felt was an amazing feeling. My kids did the same thing. Raised them right and now the grand kids are learning the same lesson. ;-)
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 116/300:
# Selected text: You think femoids will listen to whatever you have to say? Maybe you’ll get a platitude or a “well, my friend is short and girls love him.”
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 117/300:
# Selected text: Fuckable w a good personality. If they have a bad personality they aren’t fuckable but not bc of their looks.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 118/300:
# Selected text: How many fat women who got wimps locked actually started working out?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 119/300:
# Selected text: .It would cause civil war of he was taken out but it seems like he is under #ISrael's balls since he asked them 2 rescue the #WhiteHelmets from Syria not too long ago!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 120/300:
# Selected text: Who the fuck would believe that fat landwhale that someone would want to rape her lel.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 121/300:
# Selected text: Alexa Chung Her father is 3/4 Chinese if that makes a difference. I'm pretty good at spotting mixes, so she does appear a little different but definitely not appearing like half or even 3/8s asian.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 122/300:
# Selected text: I don’t date women with body imperfections. This is why if she has asymmetric breasts, stretch marks, cellulite, a weird vagina etc I ghost after the creampie
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 123/300:
# Selected text: The mormans have female cucks. We literally outlawed it because it's bad for scociety.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 124/300:
# Selected text: Does this actually work? This seems like the easiest way to get prostitutes, undercover cops, or STDs.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 125/300:
# Selected text: She's an attention whore who made her exit upon getting news about Big Brother.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 126/300:
# Selected text: Classic narcissist. Wants her cake and wants to eat it too. Block the toxic hoe and move the fuck on making yourself the priority.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 127/300:
# Selected text: I'm sure BB will cover the story when the coalburner and her sprog pays the toll!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 128/300:
# Selected text: Can't hit girls though......but.... a c@#t punt might be an idea..
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 129/300:
# Selected text: Oh my GAWD! This woman needs to be cuffed immediatly [URL] I can not wait to see what #Wikileaks has in store next week! .... Is this the work of #KimDotCom Something is getting ready to explode Major #FreedomBoner
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 130/300:
# Selected text: she says nothing but i know she wishes she had aborted me or that i would die.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 131/300:
# Selected text: Typical praising of women and bashing of men. They're so predictable. And dumb.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 132/300:
# Selected text: It's so nice to see these ideas delivered unapologetically, with no concern given to the poor hurt feelings of the feminists who are wrong about them. I'd love to send this blogger some flowers. (Or she might prefer weed. Or catnip.)
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 133/300:
# Selected text: Go for more traditional women. They cheat at a far lower rate than city girls.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 134/300:
# Selected text: statistic.. because women don't find plurals attractive, i say statistic not statistics stay true to yourselves fat shy introverts
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 135/300:
# Selected text: All minority characters are good. Only exception: if they are male, all their skill is immediately superseded by any woman.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 136/300:
# Selected text: "Only love can beat hate!" It was not love that drove the Ottomans from Europe and liberated those they subjugated and oppressed, it was the winged hussars might and bravery.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 137/300:
# Selected text: No thank you I've had my self-confidence destroyed by Indian women since birth
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 138/300:
# Selected text: ‪Import the third world and become the third world. You won’t see feminists protesting about this. ‬ ‪[URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 139/300:
# Selected text: Feminist ignore RACE when it comes to rape statistics - are cops falsely arresting nignogs darkies for rape? Or are nignog darkies raping whityle women as if nignogs are too retarded for civil society?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 140/300:
# Selected text: I'm so relieved to hear that, because I've been saving this pic since the 1930's
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 141/300:
# Selected text: [URL] Obviously written by an incel
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 142/300:
# Selected text: The new Europeans are into all kinds of sex....
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 143/300:
# Selected text: either shes a ho or shes not. If shes not u got no shot in 5 minutes. If she is it don't matter what you say ur golden.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 144/300:
# Selected text: [USER] Like I posted in another post about disgusting b!tch, if she EVER has one I'm calling it premeditated murder!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 145/300:
# Selected text: She had a strong legal team for that manipulated her testimony for that very reason. To construct a testimony that would protect her from the consequences of her actions.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 146/300:
# Selected text: This bitch needs to be shot and killed.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 147/300:
# Selected text: [URL] he should have punched her out she is nothing but a hag from the uk feel free to punch ex pats they are excrement
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 148/300:
# Selected text: Greens, eh? The fateful question of the Occident is thus now whether young female university graduates can be continually served with yoga and Pilates courses even amidst the ruins looming on the horizon.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 149/300:
# Selected text: Fucking lol. Bitches love trinkets.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 150/300:
# Selected text: Providing Emotional Support is gay. The best way to pull anyone women included out of depression is squats and nutritious food. You should be leading your girlfriend not being her vagina boy. She already has a vagina she doesn't need a second.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 151/300:
# Selected text: This must have been going on for such a long time that women have actually evolved their evil ways through the millenia.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 152/300:
# Selected text: #2AShallNotBeInfringed #NRA
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 153/300:
# Selected text: I suspect an ugly woman is the prosecuter. Ugly parent turned her in. Ugly women are criminalizing being hot. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 154/300:
# Selected text: Among letters attesting to her ‘good character’ was one written by her carpenter husband of 13 years, Paul, 34. He helped her cover her face as she arrived at court for yesterday’s hearing. Double pussy pass! Idiot husband deserves what he gets.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 155/300:
# Selected text: Good god I'd crawl bare-belly over broken beer bottles just to watch her pee
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 156/300:
# Selected text: I would love to suck her tits
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 157/300:
# Selected text: [USER] "year round winter wear, for the icy elite bitch of today." she shears her sheep and wears their wool as a sign of dominance.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 158/300:
# Selected text: The black African will soon be labeling her a racist. Race card coming soon
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 159/300:
# Selected text: "THIS is the beauty of concealed carry #GunsSaveLives" by [USER] [URL] , i live in canaduh wish we had women like that here .... sigh
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 160/300:
# Selected text: Imagine having to work with a woman along with all the stress from your other responsibilities. I've been there bro it fucking sucks, but be careful always, they will use their gender to their advantage.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 161/300:
# Selected text: Maybe to women that's what slaying means. But to men it's just racking up a pussy count.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 162/300:
# Selected text: This is about false rape charges and how wives use the laws to torture and get money from the brides family.....highly recommend to watch full video ....its mind blowing
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 163/300:
# Selected text: You should've hit her.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 164/300:
# Selected text: other vapid whore. fuck the off like kindly "I'm you girls" not
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 165/300:
# Selected text: Whores pimped out by ma n pa.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 166/300:
# Selected text: Thanks for the response brotha, I'll work towards it. It's just another nasty remnant of my beta days. But like you said, I'm a man. Men conquer.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 167/300:
# Selected text: If You Thought Ashley Graham Couldn’t Get Any Worse, You Haven’t Seen Her In A Mullet [URL] [URL]
# ...
# Selected text: Miss Pony [USER] posting her own home made porn photos Your one sick bitch !
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 258/300:
# Selected text: How do you make Lady Gaga scream? Bite her clit off.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 259/300:
# Selected text: That's female fantasy. I have a lot of experience in that field and nurses marry doctors all the time. Something statistics also support.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 260/300:
# Selected text: What an evil traitorous bitch
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 261/300:
# Selected text: OMG you think I can slay Asian pussy I already have 5 Asian girlfriends but I need 10 to not be considered an incel. I’m going to take over the whole continent
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 262/300:
# Selected text: Well if you have a penis you have to wear skinny jeans and be a beta, if you own a vagina, don't wash it for a week and bow up and act tough BUT be sure to scream "you hit a girl" if you're punched. Oh and if you see a car coming MOVE OUT OF THE WAY!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 263/300:
# Selected text: Women in the military is a joke. Almost any man could beat the shit out of this female guard wearing camo in Penn Station.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 264/300:
# Selected text: No, it's called 'guys like girls that look like bimbos' and it's a trend that needs to die. Yes, some of it is uncanny territory, but the botox lips and hooker paint job is a design choice.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 265/300:
# Selected text: penis 5.5 inch
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 266/300:
# Selected text: Womyn are always on the market, or to put it in another way: she's not yours, it's just your turn.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 267/300:
# Selected text: Old man mogs everyone in this sub
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 268/300:
# Selected text: Don't pay attention to what women say.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 269/300:
# Selected text: They are just so pissed off cuz no woman wants neither one of them and they know it. Both little fat round pigs who probably play tiddlywinks together!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 270/300:
# Selected text: #Italy: #Muslim #migrant gropes American student’s girlfriend, then #stabs the student twice: [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 271/300:
# Selected text: Yeah, I was just trying to annoy the gymcels. Anyone who's anyone knows femoids are incapable of love.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 272/300:
# Selected text: Why do women settle down with you after you spent your youth getting your dick wet with as many different pussies as you can? Because people change over time, they mature, they become different than they were ten years ago.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 273/300:
# Selected text: So you run back to daddy whenever you need help. I thought men were sooo bad? Lol. Like I said at the end you need the help of men and can't do shit on your own. Your dad must be a major cuck to raise such a stupid daughter, what went wrong
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 274/300:
# Selected text: then you get a quick brush on her boob....seems like a solid plan.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 275/300:
# Selected text: [URL] Guess who's birthday, which lord and savior that one women in that video from comet children and bondage was referencing. Guess who the Hell that disgusting bitch was fucking referencing! #PizzaGate guess what month where fucking in right now.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 276/300:
# Selected text: merkel is stazi she has to go
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 277/300:
# Selected text: white girl is trash Truly surprising
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 278/300:
# Selected text: But he’s tall, surely she wouldn’t cheat on him with a 5’11 Jeremy Meeks
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 279/300:
# Selected text: Drown her in pigs blood!!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 280/300:
# Selected text: One time I approached a group of three girls with a simple "can I drink with you" because I was attracted to one of the girls. Her friend tried to 'guard' her until I started hitting on her instead for her personality.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 281/300:
# Selected text: Only people in my office in a shitty mood today: Our token "Wise latina" and the silly single mom beaner burner. Engineering group is all grins (also, all white and all male), even their intern is wearing a red MAGA hate. LOL.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 282/300:
# Selected text: This woman is just stupid. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 283/300:
# Selected text: I’d pay a weeks salary to have the opportunity to bitch slap that smarmy look off her face. God I hope she isn’t a grandma. What a nightmare for a kid. She is anything but huggable and boo-boo kissing material.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 284/300:
# Selected text: A kilt is generally fairly heavy-duty and made of wool. A skirt is generally lighter weight.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 285/300:
# Selected text: The boys must be gaming because there goes the wifi.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 286/300:
# Selected text: Dude, it took me 10 minutes to figure out these were before and after pics. At first I didn't believe that most women hit the wall hard at 30. This was a really fucking mind opener
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 287/300:
# Selected text: Freedom? Yep, every year when I pay my taxes so a bunch of third world scum can steal the money and rape our women, I thank those vets for giving me that freedom!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 288/300:
# Selected text: And if he was a male sex slave he'd bitch and whine
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 289/300:
# Selected text: It probably wanted to suicide but was too much of a pussy.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 290/300:
# Selected text: If the court sides with the workers on this, businesses will not be able to cope with a cost of operations that is larger than incoming sales revenue.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 291/300:
# Selected text: Half the human population counts as a 'minority' to you? Some women don't give a shit about pushing paper as an office drone for 50 years of their life.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 292/300:
# Selected text: Yeah and that's why she kissed me like it was her last kiss, how about that bitch ?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 293/300:
# Selected text: My cat I had for 15 years died and I broke down a little infront of a plate. Absolutely nothing changed. Just never bring it up again. Think of it as a test for her. If she leaves, she was trash to begin with.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 294/300:
# Selected text: Karma's a bitch!
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 295/300:
# Selected text: Female logic tends to not be very logical, this especially applies to advice they give.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 296/300:
# Selected text: Ask her
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 297/300:
# Selected text: "just smile even though you want to kill yourself, bro"
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 298/300:
# Selected text: maybe 10 years ago, now she's too fat and too mommy
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 299/300:
# Selected text: Rrrrrr im going to fuck u in the ass for this
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 300/300:
# Selected text: Looks like a tranny witch
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Results Summary:
# Overall Accuracy: 58.67%
# Sexist Accuracy: 97.33% (146/150)
# Not Sexist Accuracy: 20.00% (30/150)
#
# Results saved to:
# - results/test_results_2025-01-09_21-19-07.csv
# - results/test_metadata_2025-01-09_21-19-07.json
#
# Total execution time: 0:05:43.599164
# Average time per sample: 0:00:03.435992
#
# Test Summary:
# Total samples tested: 300
# Accuracy: 58.67%
# Results: [{'sample_idx': 52, 'text': 'Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 256, 'text': "No where near as bad as the average wife who not just prey's on the husband via divorce court, but destroys children's lives while she's at it.", 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 70, 'text': 'Hillary Clinton fucking delivered a damn BlackHawk helicopter to ISIS Leader Baghdadi as a GIFT!!!! How sweet of her!!! The Bitch!', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 226, 'text': "Twitter hasn't suspended the account? They must really hate guys and whites lol", 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 57, 'text': 'oh no! So they are saying if I send my daught to college she might.... put on a hat? OH THE HUMANITY!!!!', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 16, 'text': 'Giving women all your money is good personality.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 94, 'text': 'I hate when I see a nigga come /this close 👌/ to saying women need to stick to our roles, but then adds just a pinch of feminist bullshit in a cucked attempt to not look "sexist".', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 119, 'text': 'You’re overthinking it completely. Whether you sit next to her or not next time you see her talk to her and ask her out...', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 102, 'text': '#EmpressMichelle just needs to pack her shit, #stfu and move to Venezuela. Thank you to all the #Libtards who gave us these two pieces of shit [URL]', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 97, 'text': "Damn right. Contraceptives and carpet bombs. We made 'em, we can take 'em out. It is our right as the reason why they exist in the first place, we are their gods. We can giveth and we can taketh away. / Too far ?", 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 1, 'text': 'Look at those eyes. Either someone unexpectedly just fisted her up the dumper, or that bitch is certifiably a nutburger.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 221, 'text': 'If your a simp women will destroy you. If you tell them to fuck off they are MUCH more likely to leave you alone. Choose.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 231, 'text': 'Like the "stunning and brave" woman that """stopped the police""" by showing her pussy. As if police was there only for her...', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 222, 'text': 'Damn Global Warming! [URL]', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 48, 'text': 'First. Black Democrats upset that Black unemployment is down. Now. Feminists upset with good looking women so they get Grid girls fired. Next. LGBTQ community wants AIDS to come back.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 290, 'text': 'I had one punch me in the stomach. I return the favor back. First time I ever punch a lady(monster)', 't ...

# %% [markdown]
# ## Run with Phi-3

# %%
import time, random
from datetime import timedelta

# Run test on n samples
start_time = time.time()
phi3_results = test_random_samples_with_timing(phi3_model, phi3_tokenizer, test_df, prompt, num_samples=300)
total_time = time.time() - start_time
print(f"\nTotal execution time: {str(timedelta(seconds=total_time))}")
print(f"Average time per sample: {str(timedelta(seconds=total_time/100))}")
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# Sample 1/300:
# Selected text: Overheard at Star Wars RPG Night: “I cut open the door with my lightsaber and roll through the hole in one move. Best use of a Triumph EVER!” Me: “I don’t know. I once saw a guy pick up 3 hot girls in a TR-3.”
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 2/300:
# Selected text: Basically they are together and I only saw them twice and she never spoke to me as her dad was there
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 3/300:
# Selected text: What seems to be the case is.... if a female puts in her bio “Venmo me and see what happens”, “if you are not rich don’t HMU”, “if you are fat don’t HMU” then it’s perfectly fine but if a guy has some standards, apparently im a piece of shit.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 4/300:
# Selected text: Fucking lol. Bitches love trinkets.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 5/300:
# Selected text: Depends on the girl, on both sides of this. Average girl gives an average blowjob, paid or not. And you can get high end escorts, or just more willing girls where it’s all on the table.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 6/300:
# Selected text: One time I approached a group of three girls with a simple "can I drink with you" because I was attracted to one of the girls. Her friend tried to 'guard' her until I started hitting on her instead for her personality.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 7/300:
# Selected text: Chelsea Clinton leaned over to her husband and said something about Melania. Not sure what she said, but I guarantee it was classless. #PresidentialDebates
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 8/300:
# Selected text: Female logic tends to not be very logical, this especially applies to advice they give.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 9/300:
# Selected text: I know mine is higher with smart women than dumb women. Or rather, it's lower with dumb women because my lack of knowledge or interest in what (Insert celebrity) did comes across as patronizing.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 10/300:
# Selected text: How many gun activists can attack a gun owner or their home before one of them get shot and then the activist will use it to esculate their actions including the confiscation laws you know they want.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 11/300:
# Selected text: [URL] he should have punched her out she is nothing but a hag from the uk feel free to punch ex pats they are excrement
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 12/300:
# Selected text: You think she is ready to have her genitals removed? [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 13/300:
# Selected text: CRAZY BIMBO IS BACK! White Uncle Tom: Rachel Dolezal says she's "Trans-Black." Ugh, this dumb bitch! I thought society was through with her! [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 14/300:
# Selected text: Yeah man I had a plate who did everything for me, untill she started saying I was an enigma and some people talked to me about how I was an emotionless robot with her. I opened up abit and not even a week later she lost interest.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 15/300:
# Selected text: [URL] [URL] I actually like the style of the bra popping out of the top of the dress. It looks like it was constructed that way and accentuates her curves. This dress is so vibrant and sexy--great for dancing!✨✨✨ #Beauty #GabMusic
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 16/300:
# Selected text: Yeah, I was just trying to annoy the gymcels. Anyone who's anyone knows femoids are incapable of love.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 17/300:
# Selected text: Drown her in pigs blood!!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 18/300:
# Selected text: #2AShallNotBeInfringed #NRA
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 19/300:
# Selected text: GL convincing the idiot masses ......Black pastors see Trump bringing 'new hope' -- but still need to convince their flocks .....[URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 20/300:
# Selected text: Excellent, I was just looking at another post where the female fvcked men to get grades, why support that, or even risk exposing ourselves to that type of fraudulent behavior.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 21/300:
# Selected text: I’d pay a weeks salary to have the opportunity to bitch slap that smarmy look off her face. God I hope she isn’t a grandma. What a nightmare for a kid. She is anything but huggable and boo-boo kissing material.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 22/300:
# Selected text: Modern prostitution, only you never get any bang for you buck, only an idea and a picture.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 23/300:
# Selected text: If You Thought Ashley Graham Couldn’t Get Any Worse, You Haven’t Seen Her In A Mullet [URL] [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 24/300:
# Selected text: \>woman here Opinion discarded.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 25/300:
# Selected text: Rapper Nelly settles with woman over sexual assault lawsuit. [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 26/300:
# Selected text: Im ngl short girls are cute as hell but sadlly foids dont find short men cute.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 27/300:
# Selected text: You know you've achieved peak feminism when formerly safe women are being gang raped and murdered by Africans who shouldn't be in the country and the police can't do anything to stop it.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 28/300:
# Selected text: It's a fair trade I suppose. While we'll have to pay for the incarnation of yet another rabid sheboon, likely for life she's at least removed another future negroid criminal sperm donor from the pool.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 29/300:
# Selected text: As an Eagle Scout, I'm less than pleased with all of this. If women wanted to destroy the BSA, they've done it.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 30/300:
# Selected text: Coffee, drink, walk in the park. That way if she's retarded you only wasted 20 mins of your life.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 31/300:
# Selected text: If your a simp women will destroy you. If you tell them to fuck off they are MUCH more likely to leave you alone. Choose.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 32/300:
# Selected text: It's part of the gynocentric society's effort to abolish all standards for women.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 33/300:
# Selected text: statistic.. because women don't find plurals attractive, i say statistic not statistics stay true to yourselves fat shy introverts
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 34/300:
# Selected text: Human sacrifice in the Bible psalm-1379-christian-bible-girl-baby-religion
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 35/300:
# Selected text: You have no idea what you are talking about. Just another pussy making excuses for the world you're NOT fixing.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 36/300:
# Selected text: Thats because all women are different, but all female nature is the same.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 37/300:
# Selected text: So how did men reproduce before the female virus kicked in?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 38/300:
# Selected text: Twitter hasn't suspended the account? They must really hate guys and whites lol
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 39/300:
# Selected text: #EmpressMichelle just needs to pack her shit, #stfu and move to Venezuela. Thank you to all the #Libtards who gave us these two pieces of shit [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 40/300:
# Selected text: selection bias - plus most women on tinder are there for validation not sex
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 41/300:
# Selected text: Of course I’m judgemental. If you can talk about a someone that you haven’t even meet to its fair that I get to judge you isn’t it. Or do you want to be exempt from those standards. Like a women wants.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 42/300:
# Selected text: Feminist ignore RACE when it comes to rape statistics - are cops falsely arresting nignogs darkies for rape? Or are nignog darkies raping whityle women as if nignogs are too retarded for civil society?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 43/300:
# Selected text: Well if you have a penis you have to wear skinny jeans and be a beta, if you own a vagina, don't wash it for a week and bow up and act tough BUT be sure to scream "you hit a girl" if you're punched. Oh and if you see a car coming MOVE OUT OF THE WAY!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 44/300:
# Selected text: Porn is always true
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 45/300:
# Selected text: Guys a retard , who wants attention
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 46/300:
# Selected text: Who the fuck would believe that fat landwhale that someone would want to rape her lel.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 47/300:
# Selected text: Why the fuck would you go for crazy bitches?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 48/300:
# Selected text: Worse. A whore who overestimates her own value.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 49/300:
# Selected text: Citizen Donald Trump was simply pointing out that hollywood women get so wet and excited around millionaire movies stars, they could literally be grabbed by their pussies. (He was right again!)
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 50/300:
# Selected text: All women are children
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 51/300:
# Selected text: Too many damn emojis.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 52/300:
# Selected text: Out of boredom I decided to read quite a few of the posts from cheeky monkey. My wife and I can't decide whether it's 1. A teenage girl or 2. Just a cunt I know it's possible to be both but I'm guessing it's 1 and my wife says 2.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 53/300:
# Selected text: Damn right. Contraceptives and carpet bombs. We made 'em, we can take 'em out. It is our right as the reason why they exist in the first place, we are their gods. We can giveth and we can taketh away. / Too far ?
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 54/300:
# Selected text: Pure sick evil... this woman has no soul. Kristine Marcy SES [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 55/300:
# Selected text: Yeah and that's why she kissed me like it was her last kiss, how about that bitch ?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 56/300:
# Selected text: It will not stop until women are hurt enough by genital mutilation to decide it is a bad thing. Only then can we move to ban it for boys.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 57/300:
# Selected text: It stops white women from being hit (or worse) by niggers and thats as right as it gets.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 58/300:
# Selected text: Man already jailed to be arraigned in Tucson girls' slayings [URL] #ToxicDiversity
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 59/300:
# Selected text: penis 5.5 inch
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 60/300:
# Selected text: I'm his first ever girlfriend Incels do not get girlfriends ever
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 61/300:
# Selected text: Old man mogs everyone in this sub
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 62/300:
# Selected text: This woman is just stupid. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 63/300:
# Selected text: this just this! enjoy it. what a bozo she is..... #Freaky Frederica
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 64/300:
# Selected text: I hate when I see a nigga come /this close 👌/ to saying women need to stick to our roles, but then adds just a pinch of feminist bullshit in a cucked attempt to not look "sexist".
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 65/300:
# Selected text: Well shit, you got me convinced. Where do I sign up to die in the race war, so that white women could fuck niggers without judgement?
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 66/300:
# Selected text: #Question The amount of muslims?
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 67/300:
# Selected text: I'd be shocked if it ever worked, usually these thots are getting stretched on the side, and after Leafyishere did the content nuke on her, the tier 3 subs lost it. She has a boyfriend is now etched in their collective memories
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 68/300:
# Selected text: This bitch needs to be shot and killed.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 69/300:
# Selected text: Omg if I had a quarter for all them ugly ass bitches on them apps 🤣 🤢🤮 nothing but far ugly shrek type women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 70/300:
# Selected text: The New York Times, ladies and gents: "truth is...irrelevant, we just hate Trump" #SpeakFreely #MAGA #GabFam [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 71/300:
# Selected text: Oh my GAWD! This woman needs to be cuffed immediatly [URL] I can not wait to see what #Wikileaks has in store next week! .... Is this the work of #KimDotCom Something is getting ready to explode Major #FreedomBoner
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 72/300:
# Selected text: "Muh poor oppressed women" What is this retarded faggot shit?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 73/300:
# Selected text: I don’t date women with body imperfections. This is why if she has asymmetric breasts, stretch marks, cellulite, a weird vagina etc I ghost after the creampie
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 74/300:
# Selected text: I don't know if it would make it past the House but we can try to get a law passed saying that you can't turn your kid into a God damn fucking faggot ass drag queen or else you will spend some time in Federal prison getting boned up the ass.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 75/300:
# Selected text: Ask her
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 76/300:
# Selected text: What an evil traitorous bitch
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 77/300:
# Selected text: #TheView is trying to keep professional slut #StormyDaniels and her sidekick attorney relevant by having them on The View. And on a segment called “The Political View” nonetheless 😂
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 78/300:
# Selected text: Hillary Clinton fucking delivered a damn BlackHawk helicopter to ISIS Leader Baghdadi as a GIFT!!!! How sweet of her!!! The Bitch!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 79/300:
# Selected text: It hasn't for many because this greedy bastard had to try and get it all for himself.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 80/300:
# Selected text: "Where on Earth do you get all your ideas from for your sick jokes?" asked my wife. Then she fell out of her wheelchair.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 81/300:
# Selected text: 3rd World Shitholer party of criminals. Send Cortez back to her 3rd world shithole & all her supporters.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 82/300:
# Selected text: Most women find a highly educated and well traveled man sexy.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 83/300:
# Selected text: Not all Blacks are complete NIGGERS like this whore The Pure POS Nigger bitch gives others a bad name fucking cunt Should investigate where she worked and deaths
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 84/300:
# Selected text: well it is disgusting. but if she wants to get eaten out find another man
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 85/300:
# Selected text: Why did he move out? She's the cheater, she should be forced out.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 86/300:
# Selected text: It probably wanted to suicide but was too much of a pussy.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 87/300:
# Selected text: Now we need a woman come out & accuse Hillary of sexual abuse. [USER]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 88/300:
# Selected text: #Italy: #Muslim #migrant gropes American student’s girlfriend, then #stabs the student twice: [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 89/300:
# Selected text: Damn now i have an idea. Making a fake Chad account and getting multiple roasties emotionally invested and then breaking their hearts, if they even have one. I shall find out for SCIENCE.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 90/300:
# Selected text: There’s no way that bitch is coordinated enough to pull that off.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 91/300:
# Selected text: Tell that to Weev you lying shitskin son of a bitch.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 92/300:
# Selected text: How long will it take a woman to mentally move on from the situation? Cause they're fond of bringing up shit from before my ancestors
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 93/300:
# Selected text: Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 94/300:
# Selected text: Folks [USER] is what having a small cock looks like Poor little [USER]. Nobody likes him, he has a small pencil dick, he has problems meeting women, and he can't get his testosterone patch dosage correct!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 95/300:
# Selected text: Providing Emotional Support is gay. The best way to pull anyone women included out of depression is squats and nutritious food. You should be leading your girlfriend not being her vagina boy. She already has a vagina she doesn't need a second.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 96/300:
# Selected text: Not if she wants it. Only prudish women hate dirty talk from attractive men from the getgo.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 97/300:
# Selected text: Fake News media whore.... politicized and sensationalized tragedy, instrumentalized grieving victims, all to prop up ratings (perhaps her 401-k, also) for a sinking, sinking, failing, lying network...She is a A despicable, deranged pos
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 98/300:
# Selected text: Add about 400 lbs to her fat ass... And maybe
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 99/300:
# Selected text: I saw this from [USER] herself but I thought I would share [USER] 's video on it. Keep up the good work on #PizzaGate guys! This is real #News. Don't be afraid to #SpeakFreely. [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 100/300:
# Selected text: Rrrrrr im going to fuck u in the ass for this
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 101/300:
# Selected text: white girl is trash Truly surprising
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 102/300:
# Selected text: Her career literally doesn't matter, neither does her degree or diploma. Agree with the rest.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 103/300:
# Selected text: what do you think about that ? Should i pay her ? Pay whatever she's minimally entitled to legally but kick her ass to the curb.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 104/300:
# Selected text: Kick the trans in her man eat
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 105/300:
# Selected text: Are they going to record all Anti-White hate crimes? Are they going to record every Rape of young White girls by Moslems? Are they going to record every murder of Whites, by Black/Moslems?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 106/300:
# Selected text: Trump extortionist Stormy Daniels to facilitate cryptocurrency payments on her website for porn content - [URL] #news #finance #bitcoin #stormydaniels
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 107/300:
# Selected text: Abused for four years, yet she marries him after 2.5 years of abuse? If it were true, then she's a f.....g masochistic moron.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 108/300:
# Selected text: How do you make Lady Gaga scream? Bite her clit off.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 109/300:
# Selected text: Hhaaha I fucking hate women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 110/300:
# Selected text: I hate her.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 111/300:
# Selected text: Top kek. Disgusting old cripple resenting Chad for not wanting to fuck her roast beef cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 112/300:
# Selected text: My wife just left me because I'm not 'man enough'. I'll be alright after a lads night in, crying with Ben and Jerry's whilst watching some good old Sex and The City.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 113/300:
# Selected text: "just smile even though you want to kill yourself, bro"
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 114/300:
# Selected text: [URL] Obviously written by an incel
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 115/300:
# Selected text: Hahaha, what a cuckold. I would've just ghosted her. "I will not tell her what to do" YOU ARE IN A RELATIONSHIP WITH HER, ITS YOUR DUTY TO TELL HER WHAT TO DO. Cuckold motherfucker. Now it's too late, dump the bitch.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 116/300:
# Selected text: The mormans have female cucks. We literally outlawed it because it's bad for scociety.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 117/300:
# Selected text: How is ANYONE to take this whore seriously when she puts herself out there! She's been jack hammered by everyone out there that will have her, and we're suppose to take her cry for help seriously? Whore will be a whore!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 118/300:
# Selected text: That's female fantasy. I have a lot of experience in that field and nurses marry doctors all the time. Something statistics also support.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 119/300:
# Selected text: My state? I'm not Jewish. They literally won't stop until they destroy Israel and kill every Jewish person. Have you even read the Qur'an? It was created to give them a sanctuary if Nazi Germany type countries ever rose up again.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 120/300:
# Selected text: Like the "stunning and brave" woman that """stopped the police""" by showing her pussy. As if police was there only for her...
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 121/300:
# Selected text: This is about false rape charges and how wives use the laws to torture and get money from the brides family.....highly recommend to watch full video ....its mind blowing
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 122/300:
# Selected text: merkel is stazi she has to go
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 123/300:
# Selected text: I'm sure BB will cover the story when the coalburner and her sprog pays the toll!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 124/300:
# Selected text: yeah but things are different now. tradcons are part of the problem. when the muslims take over, im gonna learn arabic and im gonna have me a harem. gotta admit muslims keep their women in check
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 125/300:
# Selected text: You've seduced a girl before right? Just do the same thing with her without the kissing. Pull ya dick out and make er suck for god sakes
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 126/300:
# Selected text: 🤣🤣🤣🤣 My hubby eats healthy, as do I. Thats why. Also, he enjoys cooking as a hobby. No, he isn't a cuck, like you are. 👌👌👌👌
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 127/300:
# Selected text: Passes IHRA anti-semitism laws to shut the British people's mouths and puts pedoes on the fast track for adoption. She can not be anymore than 2 steps away from her boss, SATAN. What a cunt
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 128/300:
# Selected text: Get packing you miserable freeze-dried old Kike cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 129/300:
# Selected text: I don't see why they even bothered, nobody said cellulite wasn't natural, just that it isn't attractive at all. Oh boo hoo women have to deal with having a flawed appearance, cry me a river.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 130/300:
# Selected text: To female Bishops stop making fun of religion.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 131/300:
# Selected text: Why do women settle down with you after you spent your youth getting your dick wet with as many different pussies as you can? Because people change over time, they mature, they become different than they were ten years ago.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 132/300:
# Selected text: The lawyer chick will shoot down the McDonald's guy, every time, no matter how he looks. That's just the world that we live in. Agree to disagree, I suppose.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 133/300:
# Selected text: She had a strong legal team for that manipulated her testimony for that very reason. To construct a testimony that would protect her from the consequences of her actions.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 134/300:
# Selected text: Intolerant feminist attacks “Doctor Who” British TV show for not being transgender or black enough - Tyranny News [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 135/300:
# Selected text: A kilt is generally fairly heavy-duty and made of wool. A skirt is generally lighter weight.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 136/300:
# Selected text: Damn...this pisses me off to no end! These mother fuckers need to start gracing the halls of maximum security federal facilities!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 137/300:
# Selected text: Classic narcissist. Wants her cake and wants to eat it too. Block the toxic hoe and move the fuck on making yourself the priority.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 138/300:
# Selected text: I had one punch me in the stomach. I return the favor back. First time I ever punch a lady(monster)
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 139/300:
# Selected text: *women spend all free time trying to block male only activities*
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 140/300:
# Selected text: what have you tried already? I like to point out that nobody blinks when a smaller man starts shit with a larger man and gets his ass beat, men and women are equal right?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 141/300:
# Selected text: oh no! So they are saying if I send my daught to college she might.... put on a hat? OH THE HUMANITY!!!!
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 142/300:
# Selected text: Or watching any movies with female protagonists?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 143/300:
# Selected text: other vapid whore. fuck the off like kindly "I'm you girls" not
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 144/300:
# Selected text: [URL] Guess who's birthday, which lord and savior that one women in that video from comet children and bondage was referencing. Guess who the Hell that disgusting bitch was fucking referencing! #PizzaGate guess what month where fucking in right now.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 145/300:
# Selected text: And if he was a male sex slave he'd bitch and whine
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 146/300:
# Selected text: No where near as bad as the average wife who not just prey's on the husband via divorce court, but destroys children's lives while she's at it.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 147/300:
# Selected text: "Only love can beat hate!" It was not love that drove the Ottomans from Europe and liberated those they subjugated and oppressed, it was the winged hussars might and bravery.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 148/300:
# Selected text: Can you imagine just how incredibly butthurt the democrats would be if Trump does so well that the first female president ends up his daughter Ivanka. They try to make a witch the first female POTUS, and instead we get an angel lol. #Trump #MAGA
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 149/300:
# Selected text: Yes, let's all be LECTURED by a Jack-ass like this Jimbo Bono's Bud in Red #BoycottedOscars #BoycottHollywood
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 150/300:
# Selected text: Let’s hope her goal never materializes
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 151/300:
# Selected text: You say you're a MGTOW, why in the hell did you agree to this? She made her damn bed. Bet your ass she would have never done the same for you if you were in her situation.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 152/300:
# Selected text: Go for more traditional women. They cheat at a far lower rate than city girls.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 153/300:
# Selected text: She's an attention whore who made her exit upon getting news about Big Brother.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 154/300:
# Selected text: I only know a few black women, but they all hate men and they are all single moms with varying amounts of baby daddies. Imo if you are a black dude who can keep down a job you deserve better than a black woman.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 155/300:
# Selected text: It's so nice to see these ideas delivered unapologetically, with no concern given to the poor hurt feelings of the feminists who are wrong about them. I'd love to send this blogger some flowers. (Or she might prefer weed. Or catnip.)
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 156/300:
# Selected text: Hit her with a club on the back of the head and carry her back to your cave oonga boonga style
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 157/300:
# Selected text: Thanks for the response brotha, I'll work towards it. It's just another nasty remnant of my beta days. But like you said, I'm a man. Men conquer.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 158/300:
# Selected text: Karma's a bitch!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 159/300:
# Selected text: Absolutely! If these RINOs stab US all in the back - tossing their vote to the Democrats = WE WILL NEVER FORGET! It's a hardcore SMEAR CAMPAIGN w Hillary Clinton and her lawyers behind it all = EVIL BITCH.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 160/300:
# Selected text: I have an alt account pretending to be a woman. My mission is making FDS females as toxic as possible I've gotten thousands of up votes while posting grade A bitch shit
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 161/300:
# Selected text: If you’re 6’3” chad with a 2” dick she will find another chad. Maybe not an incel but fuck I can sympathize.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 162/300:
# Selected text: Don't think that using the word "feminine" wasn't strategic, Mo. It was. And I couldn't agree more with everything else you wrote. They attempt to bring the rest of us down to their level. Not gonna happen ... Lol, men are a gift from God.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 163/300:
# Selected text: This must have been going on for such a long time that women have actually evolved their evil ways through the millenia.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 164/300:
# Selected text: This whore deserves to be shot to death. Women have no control. I hope someone shoots her to death in jail before she goes to trial. UK has the most fucked up feminist society.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 165/300:
# Selected text: Whores pimped out by ma n pa.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 166/300:
# Selected text: I'm so sick of women hitting the wall. I'm getting a sex doll. They never do.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 167/300:
# Selected text: oh bloody summer okay then take a small gift for her hope she likes it
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 168/300:
# Selected text: Truefemcels is troll idk about fa, inb4 bbw whaling starts ranting about fa having truecel women
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 169/300:
# Selected text: You’re a bastard lol. On a side note. I think it’s photoshopped. Those legs are way to thin to support her, and she isn’t even struggling to walk.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 170/300:
# Selected text: ZUMBIS EM BRASÍLIA EP 2 - A VOLTA DO MORTO-VIVO [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 171/300:
# Selected text: having sex at 15 is not ok! Let alone a gangbang...damn.... And people like u are trying so desperately to normalize it...at 15....they are just kids man!!
# True label: not sexist
# Predicted label: not sexist
# ...
# --------------------------------------------------------------------------------
#
# Sample 261/300:
# Selected text: Only people in my office in a shitty mood today: Our token "Wise latina" and the silly single mom beaner burner. Engineering group is all grins (also, all white and all male), even their intern is wearing a red MAGA hate. LOL.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 262/300:
# Selected text: Like a typical woman, always waiting for the men to fix a problem instead of actually working on anything. Golf clap.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 263/300:
# Selected text: Greens, eh? The fateful question of the Occident is thus now whether young female university graduates can be continually served with yoga and Pilates courses even amidst the ruins looming on the horizon.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 264/300:
# Selected text: She's getting ready to ghost you, pull back a little pursing her and wait for her to reach out to you. She is probably feeling a little crowded by your attention. In the meantime hit up other girls
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 265/300:
# Selected text: you're may be right. i'm assuming for a hookup, face matters little, because of the positions they'd be in.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 266/300:
# Selected text: I've had enough of leftie bastards,they must worship the devil!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 267/300:
# Selected text: Holy fuck is this for real
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 268/300:
# Selected text: There are wise old men who have better things to do with their time and there are creeps who never had sex with a young hot women and still try it when they are older instead of doing better things.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 269/300:
# Selected text: Bitch shouldn't have come here illegally, now should she? #ByeFelicia #DeportThemAll [URL]
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 270/300:
# Selected text: I try to act confident but girls dont even look at me
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 271/300:
# Selected text: Alexa Chung Her father is 3/4 Chinese if that makes a difference. I'm pretty good at spotting mixes, so she does appear a little different but definitely not appearing like half or even 3/8s asian.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 272/300:
# Selected text: Freakish lesbian, Ellen Degenerate, has been burned out of her home in California [URL] The wildfires are cleansing fires :)
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 273/300:
# Selected text: Miss Pony [USER] posting her own home made porn photos Your one sick bitch !
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 274/300:
# Selected text: No women love chads And tyrones with the bbc Women love black men
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 275/300:
# Selected text: I'm thinking of starting a kickstarter or something to deprogram her with a scientific Psyops campaign so we don't have to endure her debased shenanigans anymore. I'll take a $million bounty if we turn her into a legit evangelical.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 276/300:
# Selected text: Are your chromosomes XX? If so, you're 100% female.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 277/300:
# Selected text: "THIS is the beauty of concealed carry #GunsSaveLives" by [USER] [URL] , i live in canaduh wish we had women like that here .... sigh
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 278/300:
# Selected text: Soy boys PMS worse than women cause it's 24/7. They get their delicate feelings hurt because of lack of testosterone...It's a problem!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 279/300:
# Selected text: yall Fuck off
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 280/300:
# Selected text: You think femoids will listen to whatever you have to say? Maybe you’ll get a platitude or a “well, my friend is short and girls love him.”
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 281/300:
# Selected text: Every fucking time. After the trial expires it's always "what is it you want from this?" ... it's standard procedure to figure out what value her pussy brings to the table.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 282/300:
# Selected text: It's a sickening thought to realize roughly half our nation's population think we're their enemy because we genuinely support our Constitution. They support Social Justice and Gender Neutrality.... #WeCanNoLongerCoexistInPeace
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 283/300:
# Selected text: Freedom? Yep, every year when I pay my taxes so a bunch of third world scum can steal the money and rape our women, I thank those vets for giving me that freedom!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 284/300:
# Selected text: [USER]: Mother of ten shares how she prepares for homeschooling! [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 285/300:
# Selected text: so they confirm being a women means being a hole. sexist pig vice! REEEEEEEE
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 286/300:
# Selected text: This is something you can either do naturally or you can't do at all. If you can't do it naturally don't even try because you'll come across as an arrogant shit and people will hate you. Find a different way to be charming. Just be yourself.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 287/300:
# Selected text: They crap on their credibility each & every day just waiting On Patriotic Americans to die of old age .. ..or a well~calculated drone strike if HRC could have her way!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 288/300:
# Selected text: No, it's called 'guys like girls that look like bimbos' and it's a trend that needs to die. Yes, some of it is uncanny territory, but the botox lips and hooker paint job is a design choice.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 289/300:
# Selected text: Does this actually work? This seems like the easiest way to get prostitutes, undercover cops, or STDs.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 290/300:
# Selected text: Good god I'd crawl bare-belly over broken beer bottles just to watch her pee
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 291/300:
# Selected text: [USER] i can't stand idiots running our nation overlooking the true domestic enemies against our constitution and our nation making them enemies to our own nation.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 292/300:
# Selected text: I get the impression that incel never skipped a meal in his life.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 293/300:
# Selected text: The boys must be gaming because there goes the wifi.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 294/300:
# Selected text: The moment my mom divorced my dad and went riding the cock carousel I knew I’d never date again. Seven years later I’ve held up. Been a great 7 years.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 295/300:
# Selected text: Fuckable w a good personality. If they have a bad personality they aren’t fuckable but not bc of their looks.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 296/300:
# Selected text: Half the human population counts as a 'minority' to you? Some women don't give a shit about pushing paper as an office drone for 50 years of their life.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 297/300:
# Selected text: This website needs stronger digital technology... shit takes way too long to post and view... need more RAM bitches!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 298/300:
# Selected text: While I agree that its a clear sign of immaturity, women still speak this way into their late 20's. The more spoiled they are the longer it lasts.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 299/300:
# Selected text: Before I decided to sack Twitter off entirely, I muted about 100 terms, things like Feminism, sexism, racism, Trump, Brexit. Massive fucking list. Made Twitter so much more fun.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 300/300:
# Selected text: The new Europeans are into all kinds of sex....
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Results Summary:
# Overall Accuracy: 62.67%
# Sexist Accuracy: 80.67% (121/150)
# Not Sexist Accuracy: 44.67% (67/150)
#
# Results saved to:
# - results/test_results_2025-01-09_21-23-59.csv
# - results/test_metadata_2025-01-09_21-23-59.json
#
# Total execution time: 0:04:51.701645
# Average time per sample: 0:00:02.917016
#
# Test Summary:
# Total samples tested: 300
# Accuracy: 62.67%
# Results: [{'sample_idx': 46, 'text': 'Overheard at Star Wars RPG Night: “I cut open the door with my lightsaber and roll through the hole in one move. Best use of a Triumph EVER!” Me: “I don’t know. I once saw a guy pick up 3 hot girls in a TR-3.”', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 81, 'text': 'Basically they are together and I only saw them twice and she never spoke to me as her dad was there', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 223, 'text': 'What seems to be the case is.... if a female puts in her bio “Venmo me and see what happens”, “if you are not rich don’t HMU”, “if you are fat don’t HMU” then it’s perfectly fine but if a guy has some standards, apparently im a piece of shit.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 163, 'text': 'Fucking lol. Bitches love trinkets.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 50, 'text': 'Depends on the girl, on both sides of this. Average girl gives an average blowjob, paid or not. And you can get high end escorts, or just more willing girls where it’s all on the table.', 'true_label': 'sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': False}, {'sample_idx': 130, 'text': 'One time I approached a group of three girls with a simple "can I drink with you" because I was attracted to one of the girls. Her friend tried to \'guard\' her until I started hitting on her instead for her personality.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 297, 'text': 'Chelsea Clinton leaned over to her husband and said something about Melania. Not sure what she said, but I guarantee it was classless. #PresidentialDebates', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 95, 'text': 'Female logic tends to not be very logical, this especially applies to advice they give.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 249, 'text': "I know mine is higher with smart women than dumb women. Or rather, it's lower with dumb women because my lack of knowledge or interest in what (Insert celebrity) did comes across as patronizing.", 'true_label': 'sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': False}, {'sample_idx': 173, 'text': 'How many gun activists can attack a gun owner or their home before one of them get shot and then the activist will use it to esculate their actions including the confiscation laws you know they want.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 36, 'text': '[URL] he should have punched her out she is nothing but a hag from the uk feel free to punch ex pats they are excrement', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 120, 'text': 'You think she is ready to have her genitals removed? [URL]', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 194, 'text': 'CRAZY BIMBO IS BACK! White Uncle Tom: Rachel Dolezal says she\'s "Trans-Black." Ugh, this dumb bitch! I thought society was through with her! [URL]', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 186, 'text': 'Yeah man I had a plate who did everything for me, untill she started saying I was an enigma and some people talked to me about how I was an emotionless robot with her. I opened up abit and not even a week later she lost interest.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sam ...

# %% [markdown]
# ## Run with Qwen-2

# %%
import time, random
from datetime import timedelta

# Run test on n samples
start_time = time.time()
qwen_results = test_random_samples_with_timing(qwen_model, qwen_tokenizer, test_df, prompt, num_samples=300)
total_time = time.time() - start_time
print(f"\nTotal execution time: {str(timedelta(seconds=total_time))}")
print(f"Average time per sample: {str(timedelta(seconds=total_time/100))}")
# Print summary of results
# Out:
# Sample 1/300:
# Selected text: Dude, it took me 10 minutes to figure out these were before and after pics. At first I didn't believe that most women hit the wall hard at 30. This was a really fucking mind opener
# True label: sexist
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.8` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:650: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `20` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 2/300:
# Selected text: Omg if I had a quarter for all them ugly ass bitches on them apps 🤣 🤢🤮 nothing but far ugly shrek type women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 3/300:
# Selected text: So how did men reproduce before the female virus kicked in?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 4/300:
# Selected text: It probably wanted to suicide but was too much of a pussy.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 5/300:
# Selected text: My cat I had for 15 years died and I broke down a little infront of a plate. Absolutely nothing changed. Just never bring it up again. Think of it as a test for her. If she leaves, she was trash to begin with.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 6/300:
# Selected text: Bitch shouldn't have come here illegally, now should she? #ByeFelicia #DeportThemAll [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 7/300:
# Selected text: Why the fuck would you go for crazy bitches?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 8/300:
# Selected text: she says nothing but i know she wishes she had aborted me or that i would die.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 9/300:
# Selected text: this just this! enjoy it. what a bozo she is..... #Freaky Frederica
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 10/300:
# Selected text: Damn now i have an idea. Making a fake Chad account and getting multiple roasties emotionally invested and then breaking their hearts, if they even have one. I shall find out for SCIENCE.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 11/300:
# Selected text: How do you make Lady Gaga scream? Bite her clit off.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 12/300:
# Selected text: This woman is just stupid. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 13/300:
# Selected text: Go for more traditional women. They cheat at a far lower rate than city girls.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 14/300:
# Selected text: I suspect an ugly woman is the prosecuter. Ugly parent turned her in. Ugly women are criminalizing being hot. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 15/300:
# Selected text: Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 16/300:
# Selected text: I hate her.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 17/300:
# Selected text: The "migrant" first eats her snatch, then the disease eats it.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 18/300:
# Selected text: The New York Times, ladies and gents: "truth is...irrelevant, we just hate Trump" #SpeakFreely #MAGA #GabFam [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 19/300:
# Selected text: It's part of the gynocentric society's effort to abolish all standards for women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 20/300:
# Selected text: This is about false rape charges and how wives use the laws to torture and get money from the brides family.....highly recommend to watch full video ....its mind blowing
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 21/300:
# Selected text: There was an experiment where the scientists were introducing the value of the money to monkeys or chimpanzees. Just little shiny discs they could trade for food and things. It didn't take the females long to start selling sex. Well, there you go.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 22/300:
# Selected text: How long will it take a woman to mentally move on from the situation? Cause they're fond of bringing up shit from before my ancestors
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 23/300:
# Selected text: Is she on GAB HERE? I have to look and see! I'll try to follow
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 24/300:
# Selected text: Banging a white girl like her [she's a felon.. ]([URL] I always love rogue white chicks. Her smile is hot.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 25/300:
# Selected text: The moment my mom divorced my dad and went riding the cock carousel I knew I’d never date again. Seven years later I’ve held up. Been a great 7 years.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 26/300:
# Selected text: Guys a retard , who wants attention
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 27/300:
# Selected text: [USER] Exactly... which is why she loved Obama. Well sorry old hag... your time is done. The world is waking up to the truth.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 28/300:
# Selected text: Miss Pony [USER] posting her own home made porn photos Your one sick bitch !
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 29/300:
# Selected text: I'm thinking of starting a kickstarter or something to deprogram her with a scientific Psyops campaign so we don't have to endure her debased shenanigans anymore. I'll take a $million bounty if we turn her into a legit evangelical.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 30/300:
# Selected text: Womyn are always on the market, or to put it in another way: she's not yours, it's just your turn.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 31/300:
# Selected text: Coffee, drink, walk in the park. That way if she's retarded you only wasted 20 mins of your life.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 32/300:
# Selected text: Thats because all women are different, but all female nature is the same.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 33/300:
# Selected text: Like a typical woman, always waiting for the men to fix a problem instead of actually working on anything. Golf clap.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 34/300:
# Selected text: She's an attention whore who made her exit upon getting news about Big Brother.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 35/300:
# Selected text: Trump extortionist Stormy Daniels to facilitate cryptocurrency payments on her website for porn content - [URL] #news #finance #bitcoin #stormydaniels
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 36/300:
# Selected text: 3rd World Shitholer party of criminals. Send Cortez back to her 3rd world shithole & all her supporters.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 37/300:
# Selected text: This website needs stronger digital technology... shit takes way too long to post and view... need more RAM bitches!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 38/300:
# Selected text: I've had enough of leftie bastards,they must worship the devil!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 39/300:
# Selected text: #Politics #GabFam #MAGA #Australia As #MSM develops a case of total silence while covering womens virtue signaling BS. Must've been the vagina hats rather than the FGM and child RAPES [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 40/300:
# Selected text: It stops white women from being hit (or worse) by niggers and thats as right as it gets.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 41/300:
# Selected text: "Only love can beat hate!" It was not love that drove the Ottomans from Europe and liberated those they subjugated and oppressed, it was the winged hussars might and bravery.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 42/300:
# Selected text: Out of boredom I decided to read quite a few of the posts from cheeky monkey. My wife and I can't decide whether it's 1. A teenage girl or 2. Just a cunt I know it's possible to be both but I'm guessing it's 1 and my wife says 2.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 43/300:
# Selected text: Mollie Tibbets deserved to die for her support of womens perjury in divorce courts to ruin mens lives. She is one dead bitch who will never ruin a mans life in a divorce court. Good riddance to this man hating bitch. #MGTOW
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 44/300:
# Selected text: Well said. Single mothers would not get this point.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 45/300:
# Selected text: Modern prostitution, only you never get any bang for you buck, only an idea and a picture.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 46/300:
# Selected text: So you run back to daddy whenever you need help. I thought men were sooo bad? Lol. Like I said at the end you need the help of men and can't do shit on your own. Your dad must be a major cuck to raise such a stupid daughter, what went wrong
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 47/300:
# Selected text: Hit her with a club on the back of the head and carry her back to your cave oonga boonga style
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 48/300:
# Selected text: Hillary Clinton fucking delivered a damn BlackHawk helicopter to ISIS Leader Baghdadi as a GIFT!!!! How sweet of her!!! The Bitch!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 49/300:
# Selected text: Only people in my office in a shitty mood today: Our token "Wise latina" and the silly single mom beaner burner. Engineering group is all grins (also, all white and all male), even their intern is wearing a red MAGA hate. LOL.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 50/300:
# Selected text: Full on crotch grab from Biden. Even the baby's mom isn't holding him that way.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 51/300:
# Selected text: She's not crying. She's probably texting her friends complaining about the Fags at the gym.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 52/300:
# Selected text: Look at those eyes. Either someone unexpectedly just fisted her up the dumper, or that bitch is certifiably a nutburger.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 53/300:
# Selected text: A kilt is generally fairly heavy-duty and made of wool. A skirt is generally lighter weight.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 54/300:
# Selected text: Why did he move out? She's the cheater, she should be forced out.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 55/300:
# Selected text: Greens, eh? The fateful question of the Occident is thus now whether young female university graduates can be continually served with yoga and Pilates courses even amidst the ruins looming on the horizon.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 56/300:
# Selected text: Pure sick evil... this woman has no soul. Kristine Marcy SES [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 57/300:
# Selected text: She's getting ready to ghost you, pull back a little pursing her and wait for her to reach out to you. She is probably feeling a little crowded by your attention. In the meantime hit up other girls
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 58/300:
# Selected text: You think femoids will listen to whatever you have to say? Maybe you’ll get a platitude or a “well, my friend is short and girls love him.”
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 59/300:
# Selected text: Whores pimped out by ma n pa.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 60/300:
# Selected text: Na he's not flirting with her so she's reading him as gay.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 61/300:
# Selected text: what have you tried already? I like to point out that nobody blinks when a smaller man starts shit with a larger man and gets his ass beat, men and women are equal right?
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 62/300:
# Selected text: Not all Blacks are complete NIGGERS like this whore The Pure POS Nigger bitch gives others a bad name fucking cunt Should investigate where she worked and deaths
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 63/300:
# Selected text: First. Black Democrats upset that Black unemployment is down. Now. Feminists upset with good looking women so they get Grid girls fired. Next. LGBTQ community wants AIDS to come back.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 64/300:
# Selected text: Looks like a tranny witch
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 65/300:
# Selected text: Yeah, I was just trying to annoy the gymcels. Anyone who's anyone knows femoids are incapable of love.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 66/300:
# Selected text: white girl is trash Truly surprising
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 67/300:
# Selected text: Of course I’m judgemental. If you can talk about a someone that you haven’t even meet to its fair that I get to judge you isn’t it. Or do you want to be exempt from those standards. Like a women wants.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 68/300:
# Selected text: It's a sickening thought to realize roughly half our nation's population think we're their enemy because we genuinely support our Constitution. They support Social Justice and Gender Neutrality.... #WeCanNoLongerCoexistInPeace
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 69/300:
# Selected text: Freakish lesbian, Ellen Degenerate, has been burned out of her home in California [URL] The wildfires are cleansing fires :)
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 70/300:
# Selected text: The Latest: Spain suspects bought weapons after first attack - Tyranny News [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 71/300:
# Selected text: i expect to have boomers dissing national socialists right up until the communists shoot them all.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 72/300:
# Selected text: "Where on Earth do you get all your ideas from for your sick jokes?" asked my wife. Then she fell out of her wheelchair.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 73/300:
# Selected text: You’re overthinking it completely. Whether you sit next to her or not next time you see her talk to her and ask her out...
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 74/300:
# Selected text: ..oh Obama, dont even start with this kenyan hominid. I always pondered..His mother is a jew, he claims to be muslim....and fagg? yet jews claimed him as his own...oh about faggs...Obama put in risk lots of people with his "Laws" and "freedom".
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 75/300:
# Selected text: *women spend all free time trying to block male only activities*
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 76/300:
# Selected text: new male successes will arise out of the ashes of lost ones like comic culture, pc gaming, herioc fantasy, boyscouts etc. may they forever remained scorned and ridiculed by women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 77/300:
# Selected text: I'm getting older and I can't keep doing that grind to spin plates / seek out new pussy. I want to be with a woman long term, but want to learn how to avoid this issue from getting in the way.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 78/300:
# Selected text: Yeah man I had a plate who did everything for me, untill she started saying I was an enigma and some people talked to me about how I was an emotionless robot with her. I opened up abit and not even a week later she lost interest.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 79/300:
# Selected text: What an evil traitorous bitch
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 80/300:
# Selected text: Hhaaha I fucking hate women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 81/300:
# Selected text: So true girls don't know what they want and can't be loyal to anyone or anything. They just ride till they get a little bored then destroy him because they can't just leave like a normal person and find a new victim. They are black widows.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 82/300:
# Selected text: She had a strong legal team for that manipulated her testimony for that very reason. To construct a testimony that would protect her from the consequences of her actions.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 83/300:
# Selected text: Damn...hot white woman
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 84/300:
# Selected text: This bitch needs to be shot and killed.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 85/300:
# Selected text: Half the human population counts as a 'minority' to you? Some women don't give a shit about pushing paper as an office drone for 50 years of their life.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 86/300:
# Selected text: [URL] Excellent video, neatly showing how women steal from men. Marriage, meritricious law and diamond rings are all jew inventions that transfer wealth from men to women.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 87/300:
# Selected text: Good - the grid girls can finally get back into F1
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 88/300:
# Selected text: Truefemcels is troll idk about fa, inb4 bbw whaling starts ranting about fa having truecel women
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 89/300:
# Selected text: How is ANYONE to take this whore seriously when she puts herself out there! She's been jack hammered by everyone out there that will have her, and we're suppose to take her cry for help seriously? Whore will be a whore!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 90/300:
# Selected text: Citizen Donald Trump was simply pointing out that hollywood women get so wet and excited around millionaire movies stars, they could literally be grabbed by their pussies. (He was right again!)
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 91/300:
# Selected text: You should've hit her.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 92/300:
# Selected text: Old man mogs everyone in this sub
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 93/300:
# Selected text: Who the fuck would believe that fat landwhale that someone would want to rape her lel.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 94/300:
# Selected text: You have no idea what you are talking about. Just another pussy making excuses for the world you're NOT fixing.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 95/300:
# Selected text: [USER] Like I posted in another post about disgusting b!tch, if she EVER has one I'm calling it premeditated murder!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 96/300:
# Selected text: [USER]: Mother of ten shares how she prepares for homeschooling! [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 97/300:
# Selected text: No she's not lmao. IRL ratings are sugarcoated. She might be a 5 or a 6 IRL, but her more accurate PSL (puahate-sluthate-lookism) rating is 4. [URL] Large nose, asymmetric jawline and a strong chin.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 98/300:
# Selected text: #EmpressMichelle just needs to pack her shit, #stfu and move to Venezuela. Thank you to all the #Libtards who gave us these two pieces of shit [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 99/300:
# Selected text: The mormans have female cucks. We literally outlawed it because it's bad for scociety.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 100/300:
# Selected text: I don’t date women with body imperfections. This is why if she has asymmetric breasts, stretch marks, cellulite, a weird vagina etc I ghost after the creampie
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 101/300:
# Selected text: I'm his first ever girlfriend Incels do not get girlfriends ever
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 102/300:
# Selected text: Get packing you miserable freeze-dried old Kike cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 103/300:
# Selected text: Ford Can we stop with all the speculation about her. She is doing exactly what the commies do. She is a commie. They lie.Period. All planned. The commies must go.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 104/300:
# Selected text: Yeah and that's why she kissed me like it was her last kiss, how about that bitch ?
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 105/300:
# Selected text: Sick fucks....santanic people need to burn in hell!!
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 106/300:
# Selected text: George Deriziotis George Deriziotis 3 hours ago And she represents the democratic party? Please, don't replace her!!! She's the PERFECT representative for the democratic party!!!﻿
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 107/300:
# Selected text: This is something you can either do naturally or you can't do at all. If you can't do it naturally don't even try because you'll come across as an arrogant shit and people will hate you. Find a different way to be charming. Just be yourself.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 108/300:
# Selected text: Human sacrifice in the Bible psalm-1379-christian-bible-girl-baby-religion
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 109/300:
# Selected text: I'd be shocked if it ever worked, usually these thots are getting stretched on the side, and after Leafyishere did the content nuke on her, the tier 3 subs lost it. She has a boyfriend is now etched in their collective memories
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 110/300:
# Selected text: penis 5.5 inch
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 111/300:
# Selected text: other vapid whore. fuck the off like kindly "I'm you girls" not
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 112/300:
# Selected text: I don't know if it would make it past the House but we can try to get a law passed saying that you can't turn your kid into a God damn fucking faggot ass drag queen or else you will spend some time in Federal prison getting boned up the ass.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 113/300:
# Selected text: Before I decided to sack Twitter off entirely, I muted about 100 terms, things like Feminism, sexism, racism, Trump, Brexit. Massive fucking list. Made Twitter so much more fun.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 114/300:
# Selected text: Are your chromosomes XX? If so, you're 100% female.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 115/300:
# Selected text: and whats new about this. a woman can be total garbage, but as long as she is fuckable she gets something.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 116/300:
# Selected text: Passes IHRA anti-semitism laws to shut the British people's mouths and puts pedoes on the fast track for adoption. She can not be anymore than 2 steps away from her boss, SATAN. What a cunt
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 117/300:
# Selected text: Every fucking time. After the trial expires it's always "what is it you want from this?" ... it's standard procedure to figure out what value her pussy brings to the table.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 118/300:
# Selected text: Yes, let's all be LECTURED by a Jack-ass like this Jimbo Bono's Bud in Red #BoycottedOscars #BoycottHollywood
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 119/300:
# Selected text: There are wise old men who have better things to do with their time and there are creeps who never had sex with a young hot women and still try it when they are older instead of doing better things.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 120/300:
# Selected text: Like the "stunning and brave" woman that """stopped the police""" by showing her pussy. As if police was there only for her...
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 121/300:
# Selected text: [URL] [URL] I actually like the style of the bra popping out of the top of the dress. It looks like it was constructed that way and accentuates her curves. This dress is so vibrant and sexy--great for dancing!✨✨✨ #Beauty #GabMusic
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 122/300:
# Selected text: One time I approached a group of three girls with a simple "can I drink with you" because I was attracted to one of the girls. Her friend tried to 'guard' her until I started hitting on her instead for her personality.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 123/300:
# Selected text: #Hillary continues to blame everyone but herself. #MAGA #PresidentTrump #FakeNews [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 124/300:
# Selected text: But he’s tall, surely she wouldn’t cheat on him with a 5’11 Jeremy Meeks
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 125/300:
# Selected text: you're may be right. i'm assuming for a hookup, face matters little, because of the positions they'd be in.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 126/300:
# Selected text: AWALT, yes, but this sounds more than a cunty wife. Get to a hospital ASAP.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 127/300:
# Selected text: The black African will soon be labeling her a racist. Race card coming soon
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 128/300:
# Selected text: Rapper Nelly settles with woman over sexual assault lawsuit. [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 129/300:
# Selected text: I'm sure BB will cover the story when the coalburner and her sprog pays the toll!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 130/300:
# Selected text: What's the going timeframe onto getting on GAB nowadays??? I'm trying to recruit hardcore since twat is going crazy with censorship.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 131/300:
# Selected text: Even us girls did this with or without our brothers. I miss those days when we loved earning money. The pride we felt was an amazing feeling. My kids did the same thing. Raised them right and now the grand kids are learning the same lesson. ;-)
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 132/300:
# Selected text: [USER] "year round winter wear, for the icy elite bitch of today." she shears her sheep and wears their wool as a sign of dominance.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 133/300:
# Selected text: Female logic tends to not be very logical, this especially applies to advice they give.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 134/300:
# Selected text: Feminist ignore RACE when it comes to rape statistics - are cops falsely arresting nignogs darkies for rape? Or are nignog darkies raping whityle women as if nignogs are too retarded for civil society?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 135/300:
# Selected text: I only know a few black women, but they all hate men and they are all single moms with varying amounts of baby daddies. Imo if you are a black dude who can keep down a job you deserve better than a black woman.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 136/300:
# Selected text: Chelsea Clinton leaned over to her husband and said something about Melania. Not sure what she said, but I guarantee it was classless. #PresidentialDebates
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 137/300:
# Selected text: It's a fair trade I suppose. While we'll have to pay for the incarnation of yet another rabid sheboon, likely for life she's at least removed another future negroid criminal sperm donor from the pool.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 138/300:
# Selected text: well it is disgusting. but if she wants to get eaten out find another man
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 139/300:
# Selected text: How many gun activists can attack a gun owner or their home before one of them get shot and then the activist will use it to esculate their actions including the confiscation laws you know they want.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 140/300:
# Selected text: Depends on the girl, on both sides of this. Average girl gives an average blowjob, paid or not. And you can get high end escorts, or just more willing girls where it’s all on the table.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 141/300:
# Selected text: The new Europeans are into all kinds of sex....
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 142/300:
# Selected text: ‪Import the third world and become the third world. You won’t see feminists protesting about this. ‬ ‪[URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 143/300:
# Selected text: I would love to suck her tits
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 144/300:
# Selected text: ZUMBIS EM BRASÍLIA EP 2 - A VOLTA DO MORTO-VIVO [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 145/300:
# Selected text: [URL] he should have punched her out she is nothing but a hag from the uk feel free to punch ex pats they are excrement
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 146/300:
# Selected text: No thank you I've had my self-confidence destroyed by Indian women since birth
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 147/300:
# Selected text: I know mine is higher with smart women than dumb women. Or rather, it's lower with dumb women because my lack of knowledge or interest in what (Insert celebrity) did comes across as patronizing.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 148/300:
# Selected text: As an Eagle Scout, I'm less than pleased with all of this. If women wanted to destroy the BSA, they've done it.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 149/300:
# Selected text: [USER] · 8h8 hours ago Shouldn’t the most infamous loser in history shut her pie hole at this point? It’s becoming an authentic tragedy. #TumblingHag [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 150/300:
# Selected text: This man deserves to be hailed a hero he looked in the eyes of an ugly four eyed hijab and gave hwr the only respect she deserves blood and death
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 151/300:
# Selected text: #2AShallNotBeInfringed #NRA
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 152/300:
# Selected text: Soy boys PMS worse than women cause it's 24/7. They get their delicate feelings hurt because of lack of testosterone...It's a problem!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 153/300:
# Selected text: Why do women settle down with you after you spent your youth getting your dick wet with as many different pussies as you can? Because people change over time, they mature, they become different than they were ten years ago.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 154/300:
# Selected text: #Italy: #Muslim #migrant gropes American student’s girlfriend, then #stabs the student twice: [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 155/300:
# Selected text: I try to act confident but girls dont even look at me
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 156/300:
# Selected text: And if he was a male sex slave he'd bitch and whine
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 157/300:
# Selected text: Giving women all your money is good personality.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 158/300:
# Selected text: How many fat women who got wimps locked actually started working out?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 159/300:
# Selected text: Damn...this pisses me off to no end! These mother fuckers need to start gracing the halls of maximum security federal facilities!
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 160/300:
# Selected text: What seems to be the case is.... if a female puts in her bio “Venmo me and see what happens”, “if you are not rich don’t HMU”, “if you are fat don’t HMU” then it’s perfectly fine but if a guy has some standards, apparently im a piece of shit.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 161/300:
# Selected text: The lawyer chick will shoot down the McDonald's guy, every time, no matter how he looks. That's just the world that we live in. Agree to disagree, I suppose.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 162/300:
# Selected text: Folks [USER] is what having a small cock looks like Poor little [USER]. Nobody likes him, he has a small pencil dick, he has problems meeting women, and he can't get his testosterone patch dosage correct!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 163/300:
# Selected text: That's female fantasy. I have a lot of experience in that field and nurses marry doctors all the time. Something statistics also support.
# True label: sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 164/300:
# Selected text: Twitter hasn't suspended the account? They must really hate guys and whites lol
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 165/300:
# Selected text: Shut it women
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 166/300:
# Selected text: Absolutely! If these RINOs stab US all in the back - tossing their vote to the Democrats = WE WILL NEVER FORGET! It's a hardcore SMEAR CAMPAIGN w Hillary Clinton and her lawyers behind it all = EVIL BITCH.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 167/300:
# Selected text: I’d pay a weeks salary to have the opportunity to bitch slap that smarmy look off her face. God I hope she isn’t a grandma. What a nightmare for a kid. She is anything but huggable and boo-boo kissing material.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 168/300:
# ...
#
# Sample 259/300:
# Selected text: Intolerant feminist attacks “Doctor Who” British TV show for not being transgender or black enough - Tyranny News [URL]
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 260/300:
# Selected text: oh no! So they are saying if I send my daught to college she might.... put on a hat? OH THE HUMANITY!!!!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 261/300:
# Selected text: The ultimate stupid nigger, his cockroach mother I'm sure is on benifits too... Useless vermin.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 262/300:
# Selected text: no, it's just not true shared environment has basically no effect on adult iq the data is clear iq is genetic just don't starve your kid or beat them after that it's genes and chance
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 263/300:
# Selected text: either shes a ho or shes not. If shes not u got no shot in 5 minutes. If she is it don't matter what you say ur golden.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 264/300:
# Selected text: All women are children
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 265/300:
# Selected text: maybe 10 years ago, now she's too fat and too mommy
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 266/300:
# Selected text: Add about 400 lbs to her fat ass... And maybe
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 267/300:
# Selected text: Freedom? Yep, every year when I pay my taxes so a bunch of third world scum can steal the money and rape our women, I thank those vets for giving me that freedom!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 268/300:
# Selected text: There’s no way that bitch is coordinated enough to pull that off.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 269/300:
# Selected text: This must have been going on for such a long time that women have actually evolved their evil ways through the millenia.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 270/300:
# Selected text: I don't see why they even bothered, nobody said cellulite wasn't natural, just that it isn't attractive at all. Oh boo hoo women have to deal with having a flawed appearance, cry me a river.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 271/300:
# Selected text: To female Bishops stop making fun of religion.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 272/300:
# Selected text: Classic narcissist. Wants her cake and wants to eat it too. Block the toxic hoe and move the fuck on making yourself the priority.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 273/300:
# Selected text: Good god I'd crawl bare-belly over broken beer bottles just to watch her pee
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 274/300:
# Selected text: Imagine having to work with a woman along with all the stress from your other responsibilities. I've been there bro it fucking sucks, but be careful always, they will use their gender to their advantage.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 275/300:
# Selected text: I have an alt account pretending to be a woman. My mission is making FDS females as toxic as possible I've gotten thousands of up votes while posting grade A bitch shit
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 276/300:
# Selected text: Hillary should also have her clearance revoked.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 277/300:
# Selected text: Drown her in pigs blood!!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 278/300:
# Selected text: "wtf do you care what she does online" It she has LTR potential it cares! Has nothing to do with "sadness" "desperate" or "buthurt"
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 279/300:
# Selected text: Damn right. Contraceptives and carpet bombs. We made 'em, we can take 'em out. It is our right as the reason why they exist in the first place, we are their gods. We can giveth and we can taketh away. / Too far ?
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 280/300:
# Selected text: merkel is stazi she has to go
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 281/300:
# Selected text: I hope the DOJ goes after EVERY DEMOCRAT for ANY tax, bank, campaign fraud they can find. ANY of it! EVEN IF from 10 years ago. These political prosecutions will only end when the dems cry "Uncle!"
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 282/300:
# Selected text: You know you've achieved peak feminism when formerly safe women are being gang raped and murdered by Africans who shouldn't be in the country and the police can't do anything to stop it.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 283/300:
# Selected text: I see. I hope that your balls are metaphorical, little lady.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 284/300:
# Selected text: Worse. A whore who overestimates her own value.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 285/300:
# Selected text: No where near as bad as the average wife who not just prey's on the husband via divorce court, but destroys children's lives while she's at it.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 286/300:
# Selected text: .It would cause civil war of he was taken out but it seems like he is under #ISrael's balls since he asked them 2 rescue the #WhiteHelmets from Syria not too long ago!
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 287/300:
# Selected text: No. First my mom became a whore after dad left and was a huge bitch! Oh god, why won't she love me?!
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 288/300:
# Selected text: "THIS is the beauty of concealed carry #GunsSaveLives" by [USER] [URL] , i live in canaduh wish we had women like that here .... sigh
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 289/300:
# Selected text: Raising women and children is demeaning. Allowing strangers to fuck you at will and aborting their unborn children with no consequences of fatherhood is empowering. #feminismiscancer
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 290/300:
# Selected text: I'm so relieved to hear that, because I've been saving this pic since the 1930's
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 291/300:
# Selected text: You say you're a MGTOW, why in the hell did you agree to this? She made her damn bed. Bet your ass she would have never done the same for you if you were in her situation.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 292/300:
# Selected text: CRAZY BIMBO IS BACK! White Uncle Tom: Rachel Dolezal says she's "Trans-Black." Ugh, this dumb bitch! I thought society was through with her! [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 293/300:
# Selected text: While I agree that its a clear sign of immaturity, women still speak this way into their late 20's. The more spoiled they are the longer it lasts.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 294/300:
# Selected text: If You Thought Ashley Graham Couldn’t Get Any Worse, You Haven’t Seen Her In A Mullet [URL] [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 295/300:
# Selected text: Top kek. Disgusting old cripple resenting Chad for not wanting to fuck her roast beef cunt.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 296/300:
# Selected text: Fuckable w a good personality. If they have a bad personality they aren’t fuckable but not bc of their looks.
# True label: not sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 297/300:
# Selected text: Alexa Chung Her father is 3/4 Chinese if that makes a difference. I'm pretty good at spotting mixes, so she does appear a little different but definitely not appearing like half or even 3/8s asian.
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 298/300:
# Selected text: Damn Global Warming! [URL]
# True label: not sexist
# Predicted label: not sexist
# --------------------------------------------------------------------------------
#
# Sample 299/300:
# Selected text: Fucking lol. Bitches love trinkets.
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Sample 300/300:
# Selected text: As if reading your BS would make me an intellectual. Women are more than willing to date damaged men as long as the guy is hot. They don't care about "work", they care about looks. [URL]
# True label: sexist
# Predicted label: sexist
# --------------------------------------------------------------------------------
#
# Results Summary:
# Overall Accuracy: 72.33%
# Sexist Accuracy: 93.33% (140/150)
# Not Sexist Accuracy: 51.33% (77/150)
#
# Results saved to:
# - results/test_results_2025-01-09_21-27-56.csv
# - results/test_metadata_2025-01-09_21-27-56.json
#
# Total execution time: 0:03:57.730936
# Average time per sample: 0:00:02.377309
#
# Test Summary:
# Total samples tested: 300
# Accuracy: 72.33%
# Results: [{'sample_idx': 263, 'text': "Dude, it took me 10 minutes to figure out these were before and after pics. At first I didn't believe that most women hit the wall hard at 30. This was a really fucking mind opener", 'true_label': 'sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': False}, {'sample_idx': 99, 'text': 'Omg if I had a quarter for all them ugly ass bitches on them apps 🤣 🤢🤮 nothing but far ugly shrek type women.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 210, 'text': 'So how did men reproduce before the female virus kicked in?', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 112, 'text': 'It probably wanted to suicide but was too much of a pussy.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 191, 'text': 'My cat I had for 15 years died and I broke down a little infront of a plate. Absolutely nothing changed. Just never bring it up again. Think of it as a test for her. If she leaves, she was trash to begin with.', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 63, 'text': "Bitch shouldn't have come here illegally, now should she? #ByeFelicia #DeportThemAll [URL]", 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 214, 'text': 'Why the fuck would you go for crazy bitches?', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 265, 'text': 'she says nothing but i know she wishes she had aborted me or that i would die.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 255, 'text': 'this just this! enjoy it. what a bozo she is..... #Freaky Frederica', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 289, 'text': 'Damn now i have an idea. Making a fake Chad account and getting multiple roasties emotionally invested and then breaking their hearts, if they even have one. I shall find out for SCIENCE.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 40, 'text': 'How do you make Lady Gaga scream? Bite her clit off.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 234, 'text': 'This woman is just stupid. [URL]', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 83, 'text': 'Go for more traditional women. They cheat at a far lower rate than city girls.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 20, 'text': 'I suspect an ugly woman is the prosecuter. Ugly parent turned her in. Ugly women are criminalizing being hot. [URL]', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 52, 'text': 'Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 254, 'text': 'I hate her.', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 54, 'text': 'The "migrant" first eats her snatch, then the disease eats it.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 100, 'text': 'The New York Times, ladies and gents: "truth is...irrelevant, we just hate Trump" #SpeakFreely #MAGA #GabFam [URL]', 'true_label': 'not sexist', 'predicted_label': 'not sexis ...

# %%
# Save zero-shot results
save_model_results(mistral_results, "Mistral")
save_model_results(phi3_results, "Phi-3")
save_model_results(qwen_results, "Qwen-2")
# Out:
# [{'sample_idx': 263, 'text': "Dude, it took me 10 minutes to figure out these were before and after pics. At first I didn't believe that most women hit the wall hard at 30. This was a really fucking mind opener", 'true_label': 'sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': False}, {'sample_idx': 99, 'text': 'Omg if I had a quarter for all them ugly ass bitches on them apps 🤣 🤢🤮 nothing but far ugly shrek type women.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 210, 'text': 'So how did men reproduce before the female virus kicked in?', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 112, 'text': 'It probably wanted to suicide but was too much of a pussy.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 191, 'text': 'My cat I had for 15 years died and I broke down a little infront of a plate. Absolutely nothing changed. Just never bring it up again. Think of it as a test for her. If she leaves, she was trash to begin with.', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 63, 'text': "Bitch shouldn't have come here illegally, now should she? #ByeFelicia #DeportThemAll [URL]", 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 214, 'text': 'Why the fuck would you go for crazy bitches?', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 265, 'text': 'she says nothing but i know she wishes she had aborted me or that i would die.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 255, 'text': 'this just this! enjoy it. what a bozo she is..... #Freaky Frederica', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 289, 'text': 'Damn now i have an idea. Making a fake Chad account and getting multiple roasties emotionally invested and then breaking their hearts, if they even have one. I shall find out for SCIENCE.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 40, 'text': 'How do you make Lady Gaga scream? Bite her clit off.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 234, 'text': 'This woman is just stupid. [URL]', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 83, 'text': 'Go for more traditional women. They cheat at a far lower rate than city girls.', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 20, 'text': 'I suspect an ugly woman is the prosecuter. Ugly parent turned her in. Ugly women are criminalizing being hot. [URL]', 'true_label': 'sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': True}, {'sample_idx': 52, 'text': 'Ah, /r/redpillwomen, where ladies are free to speak their minds about any subject they like, so long as it involves either trading recipes or bashing Gloria Steinem. And nothing else.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 254, 'text': 'I hate her.', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_response': 'NO', 'correct': True}, {'sample_idx': 54, 'text': 'The "migrant" first eats her snatch, then the disease eats it.', 'true_label': 'not sexist', 'predicted_label': 'sexist', 'raw_response': 'YES', 'correct': False}, {'sample_idx': 100, 'text': 'The New York Times, ladies and gents: "truth is...irrelevant, we just hate Trump" #SpeakFreely #MAGA #GabFam [URL]', 'true_label': 'not sexist', 'predicted_label': 'not sexist', 'raw_ ...

# %% [markdown]
# # [Task 4] Metrics

# %%
def compute_metrics(results):
    """
    Compute metrics with proper error handling
    """
    # Check if results is empty
    if not results:
        return {
            'accuracy': 0.0,
            'fail_ratio': 0.0,
            'total_samples': 0,
            'failed_samples': 0,
            'correct_predictions': 0,
            'valid_predictions': 0,
            'sexist_accuracy': 0.0,
            'not_sexist_accuracy': 0.0,
            'sexist_correct': 0,
            'sexist_total': 0,
            'not_sexist_correct': 0,
            'not_sexist_total': 0
        }

    total_samples = len(results)
    failed_samples = 0
    correct_predictions = 0
    sexist_correct = 0
    sexist_total = 0
    not_sexist_correct = 0
    not_sexist_total = 0

    for result in results:
        if result['true_label'] == 'sexist':
            sexist_total += 1
            if result['correct']:
                sexist_correct += 1
        else:
            not_sexist_total += 1
            if result['correct']:
                not_sexist_correct += 1

        raw_response = result['raw_response'].strip().upper()
        if raw_response not in ['YES', 'NO']:
            failed_samples += 1
            continue

        if result['correct']:
            correct_predictions += 1

    valid_predictions = total_samples - failed_samples
    fail_ratio = failed_samples / total_samples if total_samples > 0 else 0.0
    accuracy = correct_predictions / valid_predictions if valid_predictions > 0 else 0.0
    sexist_accuracy = sexist_correct / sexist_total if sexist_total > 0 else 0.0
    not_sexist_accuracy = not_sexist_correct / not_sexist_total if not_sexist_total > 0 else 0.0

    return {
        'accuracy': accuracy,
        'fail_ratio': fail_ratio,
        'total_samples': total_samples,
        'failed_samples': failed_samples,
        'correct_predictions': correct_predictions,
        'valid_predictions': valid_predictions,
        'sexist_accuracy': sexist_accuracy,
        'not_sexist_accuracy': not_sexist_accuracy,
        'sexist_correct': sexist_correct,
        'sexist_total': sexist_total,
        'not_sexist_correct': not_sexist_correct,
        'not_sexist_total': not_sexist_total
    }

# %%
def print_model_results(model_name, results):
    """
    Pretty print the metrics results for a given model
    """
    metrics = compute_metrics(results)

    # Create a styled header
    header = f"\n{'='*50}"
    model_title = f"| {model_name.upper()} RESULTS |"

    print(header)
    print(model_title.center(50))
    print(header)

    # Print main metrics
    print("\nMAIN METRICS:")
    print(f"• Overall Accuracy: {metrics['accuracy']:.2%}")
    print(f"• Fail Ratio: {metrics['fail_ratio']:.2%}")

    # Print detailed counts
    print("\nDETAILED COUNTS:")
    print(f"• Total Samples: {metrics['total_samples']}")
    print(f"• Valid Predictions: {metrics['valid_predictions']}")
    print(f"• Failed Responses: {metrics['failed_samples']}")
    print(f"• Correct Predictions: {metrics['correct_predictions']}")

    # Print class-specific metrics
    print("\nCLASS-SPECIFIC PERFORMANCE:")
    print(f"• Sexist Accuracy: {metrics['sexist_accuracy']:.2%} "
          f"({metrics['sexist_correct']}/{metrics['sexist_total']})")
    print(f"• Not Sexist Accuracy: {metrics['not_sexist_accuracy']:.2%} "
          f"({metrics['not_sexist_correct']}/{metrics['not_sexist_total']})")

    print(header + "\n")

    return metrics
# Out:
# ==================================================
#                | MISTRAL RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 58.67%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 176
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 97.33% (146/150)
# • Not Sexist Accuracy: 20.00% (30/150)
#
# ==================================================
#
#
# ==================================================
#                 | PHI-3 RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 62.67%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 188
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 80.67% (121/150)
# • Not Sexist Accuracy: 44.67% (67/150)
#
# ==================================================
#
#
# ==================================================
#                  | QWEN RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 72.33%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 217
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 93.33% (140/150)
# • Not Sexist Accuracy: 51.33% (77/150)
#
# ==================================================
# {'accuracy': 0.7233333333333334,
#  'fail_ratio': 0.0,
#  'total_samples': 300,
#  'failed_samples': 0,
#  'correct_predictions': 217,
#  'valid_predictions': 300,
#  'sexist_accuracy': 0.9333333333333333,
#  'not_sexist_accuracy': 0.5133333333333333,
#  'sexist_correct': 140,
#  'sexist_total': 150,
#  'not_sexist_correct': 77,
#  'not_sexist_total': 150}

# %%
# Print results for each model
print_model_results("Mistral", mistral_results)
print_model_results("Phi-3", phi3_results)
print_model_results("Qwen", qwen_results)
# Out:
# ==================================================
#                | MISTRAL RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 58.67%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 176
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 97.33% (146/150)
# • Not Sexist Accuracy: 20.00% (30/150)
#
# ==================================================
#
#
# ==================================================
#                 | PHI-3 RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 62.67%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 188
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 80.67% (121/150)
# • Not Sexist Accuracy: 44.67% (67/150)
#
# ==================================================
#
#
# ==================================================
#                  | QWEN RESULTS |
#
# ==================================================
#
# MAIN METRICS:
# • Overall Accuracy: 72.33%
# • Fail Ratio: 0.00%
#
# DETAILED COUNTS:
# • Total Samples: 300
# • Valid Predictions: 300
# • Failed Responses: 0
# • Correct Predictions: 217
#
# CLASS-SPECIFIC PERFORMANCE:
# • Sexist Accuracy: 93.33% (140/150)
# • Not Sexist Accuracy: 51.33% (77/150)
#
# ==================================================
# {'accuracy': 0.7233333333333334,
#  'fail_ratio': 0.0,
#  'total_samples': 300,
#  'failed_samples': 0,
#  'correct_predictions': 217,
#  'valid_predictions': 300,
#  'sexist_accuracy': 0.9333333333333333,
#  'not_sexist_accuracy': 0.5133333333333333,
#  'sexist_correct': 140,
#  'sexist_total': 150,
#  'not_sexist_correct': 77,
#  'not_sexist_total': 150}

# %% [markdown]
# # [Task 5] Few-show inference

# %%
import pandas as pd

# Load the demonstrations.csv
url = "https://raw.githubusercontent.com/nlp-unibo/nlp-course-material/refs/heads/main/2024-2025/Assignment%202/data/demonstrations.csv"
demonstrations = pd.read_csv(url)
print(demonstrations.head())
# Out:
#                   rewire_id  \
# 0  sexism2022_english-10348
# 1   sexism2022_english-7950
# 2   sexism2022_english-7742
# 3  sexism2022_english-16170
# 4   sexism2022_english-9857
#
#                                                 text label_sexist
# 0  I would never have my kid go to a daycare with...   not sexist
# 1           Democrat women are so butt fucking ugly.       sexist
# 2  If you really wanted to twist the knife you’d ...   not sexist
# 3  Those women are pro-rape. They didn’t care abo...       sexist
# 4  Married a bitch... Is it the standard scenario...       sexist

# %%
prompt = [
    {
        'role': 'system',
        'content': 'You are an annotator for sexism detection.'
    },
    {
        'role': 'user',
        'content': """Your task is to classify input text as containing sexism or not. Respond only YES or NO.

        EXAMPLES:
        {examples}

        TEXT:
        {text}

        ANSWER:
        """
    }
]

# %%
def build_few_shot_demonstrations(demonstrations, num_shots):
    """
    Build demonstrations with specified number of shots per class.

    Args:
        demonstrations (DataFrame): DataFrame containing demonstration examples
        num_shots (int): Number of examples per class to include
    """
    # Filter and sample demonstrations
    sexist_examples = demonstrations[demonstrations['label_sexist'] == 'sexist'].sample(num_shots)
    not_sexist_examples = demonstrations[demonstrations['label_sexist'] == 'not sexist'].sample(num_shots)

    # Format examples into a string
    examples = ""
    for _, row in sexist_examples.iterrows():
        examples += f"TEXT: **{row['text']}**\nANSWER: YES\n"
    for _, row in not_sexist_examples.iterrows():
        examples += f"TEXT: **{row['text']}**\nANSWER: NO\n"

    return examples

# %%
def create_prompt(text, demonstrations):
    num_per_class = 2  # or any other number you choose
    examples = build_few_shot_demonstrations(demonstrations, num_per_class)

    prompt = [
        {
            'role': 'system',
            'content': 'You are an annotator for sexism detection.'
        },
        {
            'role': 'user',
            'content': f"""Your task is to classify input text as containing sexism or not. Respond only YES or NO.

            EXAMPLES:
            {examples}

            TEXT:
            {text}

            ANSWER:
            """
        }
    ]
    return prompt

# %%
# Test example
sample_text = "Women belong in the kitchen, not in the workplace."

# Create a prompt with few-shot examples
test_prompt = create_prompt(sample_text, demonstrations)

# Print the formatted prompt to see how it looks
print("Generated Prompt Structure:")
print("\nSystem Role:")
print(test_prompt[0]['content'])
print("\nUser Role:")
print(test_prompt[1]['content'])
# Out:
# Generated Prompt Structure:
#
# System Role:
# You are an annotator for sexism detection.
#
# User Role:
# Your task is to classify input text as containing sexism or not. Respond only YES or NO.
#
#             EXAMPLES:
#             TEXT: **None of these loose mothers should be rewarded with 'real men', they should see that choosing wisely in the first place is the highest priority if they don't want a one-way trip to never again getting clearance for make-out.**
# ANSWER: YES
# TEXT: **Ahh. Yea definite shit test. If you agreed to go over there she probably would have just said “ohh wait i can’t, gotta work earlier than I thought” or some other excuse and then be happy with her validation from you wanting to come over.**
# ANSWER: YES
# TEXT: **[USER] this is not normal! Any mom that saw those pics on the wall in there would run out with her hand over her baby's eyes and never look back.**
# ANSWER: NO
# TEXT: **Damn, she is fucked up. If I was you, I'd gradually ghost her!**
# ANSWER: NO
#
#
#             TEXT:
#             Women belong in the kitchen, not in the workplace.
#
#             ANSWER:

# %%
# Run few-shot inference with Mistral
import time, random
from datetime import timedelta

def test_n_shot_samples(model, tokenizer, test_df, demonstrations, num_shots, num_samples=30):
    """
    Test model performance with specified number of shots and error handling
    """
    try:
        results = []
        device = next(model.parameters()).device
        tokenizer.pad_token = tokenizer.eos_token

        # Sample selection logic
        samples_per_class = num_samples // 2
        sexist_indices = test_df[test_df['label_sexist'] == 'sexist'].index
        not_sexist_indices = test_df[test_df['label_sexist'] == 'not sexist'].index

        selected_sexist = random.sample(list(sexist_indices), min(samples_per_class, len(sexist_indices)))
        selected_not_sexist = random.sample(list(not_sexist_indices), min(samples_per_class, len(not_sexist_indices)))
        selected_indices = selected_sexist + selected_not_sexist
        random.shuffle(selected_indices)

        for i, idx in enumerate(selected_indices):
            sample_text = test_df.iloc[idx]['text']
            true_label = test_df.iloc[idx]['label_sexist']

            # Create n-shot prompt
            examples = build_few_shot_demonstrations(demonstrations, num_shots)
            few_shot_prompt = [
                {'role': 'system', 'content': 'You are an annotator for sexism detection.'},
                {'role': 'user', 'content': f"""Your task is to classify input text as containing sexism or not. Respond only YES or NO.

                EXAMPLES:
                {examples}

                TEXT:
                {sample_text}

                ANSWER:
                """}
            ]

            formatted_prompts = prepare_prompts([sample_text], few_shot_prompt, tokenizer)

            # Move tensors to device
            for j in range(len(formatted_prompts)):
                formatted_prompts[j] = {k: v.to(device) for k, v in formatted_prompts[j].items()}

            responses = generate_responses(model, formatted_prompts)
            binary_label = process_response(responses[0])
            predicted_label = "sexist" if binary_label == 1 else "not sexist"

            results.append({
                'sample_idx': idx,
                'text': sample_text,
                'true_label': true_label,
                'predicted_label': predicted_label,
                'raw_response': responses[0],
                'correct': predicted_label == true_label
            })

            print(f"\t\t\tProgress: {i+1}/{len(selected_indices)} samples processed")
            torch.cuda.empty_cache()

        return results

    except Exception as e:
        print(f"Error during testing with {num_shots} shots: {str(e)}")
        return []

# %%
def print_shot_comparison(results_dict, model_name):
    """
    Print comparison of different numbers of shots

    Args:
        results_dict: Dictionary with number of shots as keys and results as values
        model_name: Name of the model being evaluated
    """
    header = f"\n{'='*90}"
    model_title = f"| {model_name.upper()} PERFORMANCE ACROSS DIFFERENT NUMBERS OF SHOTS |"

    print(header)
    print(model_title.center(90))
    print(header)

    # Print metrics table
    print("\nPERFORMANCE METRICS:")
    print(f"{'Metric':<20}", end='')
    for n_shots in sorted(results_dict.keys()):
        print(f"{f'{n_shots}-shot':>12}", end='')
    print()
    print("-" * 90)

    # Get metrics for each shot count
    metrics_by_shots = {
        n_shots: compute_metrics(results)
        for n_shots, results in results_dict.items()
    }

    # Print accuracy metrics
    print(f"Overall Accuracy:", end='')
    for n_shots in sorted(results_dict.keys()):
        print(f"{metrics_by_shots[n_shots]['accuracy']:>12.1%}", end='')
    print()

    print(f"Sexist Accuracy:", end='')
    for n_shots in sorted(results_dict.keys()):
        print(f"{metrics_by_shots[n_shots]['sexist_accuracy']:>12.1%}", end='')
    print()

    print(f"Not Sexist Accuracy:", end='')
    for n_shots in sorted(results_dict.keys()):
        print(f"{metrics_by_shots[n_shots]['not_sexist_accuracy']:>12.1%}", end='')
    print()

    print(header + "\n")

    return metrics_by_shots

# %%
# Test with different numbers of shots
shot_counts = [2, 4, 6, 8, 10]
test_samples = 300

# Initialize results dictionaries
mistral_shot_results = {}
phi3_shot_results = {}
qwen_shot_results = {}

# Test each model with progress tracking
for model_name, model_tuple in [
    ("Mistral", (mistral_model, mistral_tokenizer, mistral_shot_results)),
    ("Phi-3", (phi3_model, phi3_tokenizer, phi3_shot_results)),
    ("Qwen-2", (qwen_model, qwen_tokenizer, qwen_shot_results))
]:
    print(f"\nTesting {model_name}...")
    model, tokenizer, results_dict = model_tuple

    for n_shots in shot_counts:
        print(f"\n\tTesting with {n_shots} shots...")
        results = test_n_shot_samples(
            model,
            tokenizer,
            test_df,
            demonstrations,
            n_shots,
            test_samples
        )
        if results:  # Only store results if they're not empty
            results_dict[n_shots] = results
        print(f"Completed {n_shots}-shot testing for {model_name}")

# Print comparisons with error handling
print("\nResults Summary:")
for model_name, results_dict in [
    ("Mistral", mistral_shot_results),
    ("Phi-3", phi3_shot_results),
    ("Qwen-2", qwen_shot_results)
]:
    if results_dict:
        print(f"\n{model_name} Results:")
        metrics = print_shot_comparison(results_dict, model_name)
    else:
        print(f"\n{model_name}: No valid results collected")
# Out:
# Testing Mistral...
#
# 	Testing with 2 shots...
# 			Progress: 1/300 samples processed
# 			Progress: 2/300 samples processed
# 			Progress: 3/300 samples processed
# 			Progress: 4/300 samples processed
# 			Progress: 5/300 samples processed
# 			Progress: 6/300 samples processed
# 			Progress: 7/300 samples processed
# 			Progress: 8/300 samples processed
# 			Progress: 9/300 samples processed
# 			Progress: 10/300 samples processed
# 			Progress: 11/300 samples processed
# 			Progress: 12/300 samples processed
# 			Progress: 13/300 samples processed
# 			Progress: 14/300 samples processed
# 			Progress: 15/300 samples processed
# 			Progress: 16/300 samples processed
# 			Progress: 17/300 samples processed
# 			Progress: 18/300 samples processed
# 			Progress: 19/300 samples processed
# 			Progress: 20/300 samples processed
# 			Progress: 21/300 samples processed
# 			Progress: 22/300 samples processed
# 			Progress: 23/300 samples processed
# 			Progress: 24/300 samples processed
# 			Progress: 25/300 samples processed
# 			Progress: 26/300 samples processed
# 			Progress: 27/300 samples processed
# 			Progress: 28/300 samples processed
# 			Progress: 29/300 samples processed
# 			Progress: 30/300 samples processed
# 			Progress: 31/300 samples processed
# 			Progress: 32/300 samples processed
# 			Progress: 33/300 samples processed
# 			Progress: 34/300 samples processed
# 			Progress: 35/300 samples processed
# 			Progress: 36/300 samples processed
# 			Progress: 37/300 samples processed
# 			Progress: 38/300 samples processed
# 			Progress: 39/300 samples processed
# 			Progress: 40/300 samples processed
# 			Progress: 41/300 samples processed
# 			Progress: 42/300 samples processed
# 			Progress: 43/300 samples processed
# 			Progress: 44/300 samples processed
# 			Progress: 45/300 samples processed
# 			Progress: 46/300 samples processed
# 			Progress: 47/300 samples processed
# 			Progress: 48/300 samples processed
# 			Progress: 49/300 samples processed
# 			Progress: 50/300 samples processed
# 			Progress: 51/300 samples processed
# 			Progress: 52/300 samples processed
# 			Progress: 53/300 samples processed
# 			Progress: 54/300 samples processed
# 			Progress: 55/300 samples processed
# 			Progress: 56/300 samples processed
# 			Progress: 57/300 samples processed
# 			Progress: 58/300 samples processed
# 			Progress: 59/300 samples processed
# 			Progress: 60/300 samples processed
# 			Progress: 61/300 samples processed
# 			Progress: 62/300 samples processed
# 			Progress: 63/300 samples processed
# 			Progress: 64/300 samples processed
# 			Progress: 65/300 samples processed
# 			Progress: 66/300 samples processed
# 			Progress: 67/300 samples processed
# 			Progress: 68/300 samples processed
# 			Progress: 69/300 samples processed
# 			Progress: 70/300 samples processed
# 			Progress: 71/300 samples processed
# 			Progress: 72/300 samples processed
# 			Progress: 73/300 samples processed
# 			Progress: 74/300 samples processed
# 			Progress: 75/300 samples processed
# 			Progress: 76/300 samples processed
# 			Progress: 77/300 samples processed
# 			Progress: 78/300 samples processed
# 			Progress: 79/300 samples processed
# 			Progress: 80/300 samples processed
# 			Progress: 81/300 samples processed
# 			Progress: 82/300 samples processed
# 			Progress: 83/300 samples processed
# 			Progress: 84/300 samples processed
# 			Progress: 85/300 samples processed
# 			Progress: 86/300 samples processed
# 			Progress: 87/300 samples processed
# 			Progress: 88/300 samples processed
# 			Progress: 89/300 samples processed
# 			Progress: 90/300 samples processed
# 			Progress: 91/300 samples processed
# 			Progress: 92/300 samples processed
# 			Progress: 93/300 samples processed
# 			Progress: 94/300 samples processed
# 			Progress: 95/300 samples processed
# 			Progress: 96/300 samples processed
# 			Progress: 97/300 samples processed
# 			Progress: 98/300 samples processed
# 			Progress: 99/300 samples processed
# 			Progress: 100/300 samples processed
# 			Progress: 101/300 samples processed
# 			Progress: 102/300 samples processed
# 			Progress: 103/300 samples processed
# 			Progress: 104/300 samples processed
# 			Progress: 105/300 samples processed
# 			Progress: 106/300 samples processed
# 			Progress: 107/300 samples processed
# 			Progress: 108/300 samples processed
# 			Progress: 109/300 samples processed
# 			Progress: 110/300 samples processed
# 			Progress: 111/300 samples processed
# 			Progress: 112/300 samples processed
# 			Progress: 113/300 samples processed
# 			Progress: 114/300 samples processed
# 			Progress: 115/300 samples processed
# 			Progress: 116/300 samples processed
# 			Progress: 117/300 samples processed
# 			Progress: 118/300 samples processed
# 			Progress: 119/300 samples processed
# 			Progress: 120/300 samples processed
# 			Progress: 121/300 samples processed
# 			Progress: 122/300 samples processed
# 			Progress: 123/300 samples processed
# 			Progress: 124/300 samples processed
# 			Progress: 125/300 samples processed
# 			Progress: 126/300 samples processed
# 			Progress: 127/300 samples processed
# 			Progress: 128/300 samples processed
# 			Progress: 129/300 samples processed
# 			Progress: 130/300 samples processed
# 			Progress: 131/300 samples processed
# 			Progress: 132/300 samples processed
# 			Progress: 133/300 samples processed
# 			Progress: 134/300 samples processed
# 			Progress: 135/300 samples processed
# 			Progress: 136/300 samples processed
# 			Progress: 137/300 samples processed
# 			Progress: 138/300 samples processed
# 			Progress: 139/300 samples processed
# 			Progress: 140/300 samples processed
# 			Progress: 141/300 samples processed
# 			Progress: 142/300 samples processed
# 			Progress: 143/300 samples processed
# 			Progress: 144/300 samples processed
# 			Progress: 145/300 samples processed
# 			Progress: 146/300 samples processed
# 			Progress: 147/300 samples processed
# 			Progress: 148/300 samples processed
# 			Progress: 149/300 samples processed
# 			Progress: 150/300 samples processed
# 			Progress: 151/300 samples processed
# 			Progress: 152/300 samples processed
# 			Progress: 153/300 samples processed
# 			Progress: 154/300 samples processed
# 			Progress: 155/300 samples processed
# 			Progress: 156/300 samples processed
# 			Progress: 157/300 samples processed
# 			Progress: 158/300 samples processed
# 			Progress: 159/300 samples processed
# 			Progress: 160/300 samples processed
# 			Progress: 161/300 samples processed
# 			Progress: 162/300 samples processed
# 			Progress: 163/300 samples processed
# 			Progress: 164/300 samples processed
# 			Progress: 165/300 samples processed
# 			Progress: 166/300 samples processed
# 			Progress: 167/300 samples processed
# 			Progress: 168/300 samples processed
# 			Progress: 169/300 samples processed
# 			Progress: 170/300 samples processed
# 			Progress: 171/300 samples processed
# 			Progress: 172/300 samples processed
# 			Progress: 173/300 samples processed
# 			Progress: 174/300 samples processed
# 			Progress: 175/300 samples processed
# 			Progress: 176/300 samples processed
# 			Progress: 177/300 samples processed
# 			Progress: 178/300 samples processed
# 			Progress: 179/300 samples processed
# 			Progress: 180/300 samples processed
# 			Progress: 181/300 samples processed
# 			Progress: 182/300 samples processed
# 			Progress: 183/300 samples processed
# 			Progress: 184/300 samples processed
# 			Progress: 185/300 samples processed
# 			Progress: 186/300 samples processed
# 			Progress: 187/300 samples processed
# 			Progress: 188/300 samples processed
# 			Progress: 189/300 samples processed
# 			Progress: 190/300 samples processed
# 			Progress: 191/300 samples processed
# 			Progress: 192/300 samples processed
# 			Progress: 193/300 samples processed
# 			Progress: 194/300 samples processed
# 			Progress: 195/300 samples processed
# 			Progress: 196/300 samples processed
# 			Progress: 197/300 samples processed
# 			Progress: 198/300 samples processed
# 			Progress: 199/300 samples processed
# 			Progress: 200/300 samples processed
# 			Progress: 201/300 samples processed
# 			Progress: 202/300 samples processed
# 			Progress: 203/300 samples processed
# 			Progress: 204/300 samples processed
# 			Progress: 205/300 samples processed
# 			Progress: 206/300 samples processed
# 			Progress: 207/300 samples processed
# 			Progress: 208/300 samples processed
# 			Progress: 209/300 samples processed
# 			Progress: 210/300 samples processed
# 			Progress: 211/300 samples processed
# 			Progress: 212/300 samples processed
# 			Progress: 213/300 samples processed
# 			Progress: 214/300 samples processed
# 			Progress: 215/300 samples processed
# 			Progress: 216/300 samples processed
# 			Progress: 217/300 samples processed
# 			Progress: 218/300 samples processed
# 			Progress: 219/300 samples processed
# 			Progress: 220/300 samples processed
# 			Progress: 221/300 samples processed
# 			Progress: 222/300 samples processed
# 			Progress: 223/300 samples processed
# 			Progress: 224/300 samples processed
# 			Progress: 225/300 samples processed
# 			Progress: 226/300 samples processed
# 			Progress: 227/300 samples processed
# 			Progress: 228/300 samples processed
# 			Progress: 229/300 samples processed
# 			Progress: 230/300 samples processed
# 			Progress: 231/300 samples processed
# 			Progress: 232/300 samples processed
# 			Progress: 233/300 samples processed
# 			Progress: 234/300 samples processed
# 			Progress: 235/300 samples processed
# 			Progress: 236/300 samples processed
# 			Progress: 237/300 samples processed
# 			Progress: 238/300 samples processed
# 			Progress: 239/300 samples processed
# 			Progress: 240/300 samples processed
# 			Progress: 241/300 samples processed
# 			Progress: 242/300 samples processed
# 			Progress: 243/300 samples processed
# 			Progress: 244/300 samples processed
# 			Progress: 245/300 samples processed
# 			Progress: 246/300 samples processed
# 			Progress: 247/300 samples processed
# 			Progress: 248/300 samples processed
# 			Progress: 249/300 samples processed
# 			Progress: 250/300 samples processed
# 			Progress: 251/300 samples processed
# 			Progress: 252/300 samples processed
# 			Progress: 253/300 samples processed
# 			Progress: 254/300 samples processed
# 			Progress: 255/300 samples processed
# 			Progress: 256/300 samples processed
# 			Progress: 257/300 samples processed
# 			Progress: 258/300 samples processed
# 			Progress: 259/300 samples processed
# 			Progress: 260/300 samples processed
# 			Progress: 261/300 samples processed
# 			Progress: 262/300 samples processed
# 			Progress: 263/300 samples processed
# 			Progress: 264/300 samples processed
# 			Progress: 265/300 samples processed
# 			Progress: 266/300 samples processed
# 			Progress: 267/300 samples processed
# 			Progress: 268/300 samples processed
# 			Progress: 269/300 samples processed
# 			Progress: 270/300 samples processed
# 			Progress: 271/300 samples processed
# 			Progress: 272/300 samples processed
# 			Progress: 273/300 samples processed
# 			Progress: 274/300 samples processed
# 			Progress: 275/300 samples processed
# 			Progress: 276/300 samples processed
# 			Progress: 277/300 samples processed
# 			Progress: 278/300 samples processed
# 			Progress: 279/300 samples processed
# 			Progress: 280/300 samples processed
# 			Progress: 281/300 samples processed
# 			Progress: 282/300 samples processed
# 			Progress: 283/300 samples processed
# 			Progress: 284/300 samples processed
# 			Progress: 285/300 samples processed
# 			Progress: 286/300 samples processed
# 			Progress: 287/300 samples processed
# 			Progress: 288/300 samples processed
# 			Progress: 289/300 samples processed
# 			Progress: 290/300 samples processed
# 			Progress: 291/300 samples processed
# 			Progress: 292/300 samples processed
# 			Progress: 293/300 samples processed
# 			Progress: 294/300 samples processed
# 			Progress: 295/300 samples processed
# 			Progress: 296/300 samples processed
# 			Progress: 297/300 samples processed
# 			Progress: 298/300 samples processed
# 			Progress: 299/300 samples processed
# 			Progress: 300/300 samples processed
# Completed 2-shot testing for Mistral
#
# 	Testing with 4 shots...
# 			Progress: 1/300 samples processed
# 			Progress: 2/300 samples processed
# 			Progress: 3/300 samples processed
# 			Progress: 4/300 samples processed
# 			Progress: 5/300 samples processed
# 			Progress: 6/300 samples processed
# 			Progress: 7/300 samples processed
# 			Progress: 8/300 samples processed
# 			Progress: 9/300 samples processed
# 			Progress: 10/300 samples processed
# 			Progress: 11/300 samples processed
# 			Progress: 12/300 samples processed
# 			Progress: 13/300 samples processed
# 			Progress: 14/300 samples processed
# 			Progress: 15/300 samples processed
# 			Progress: 16/300 samples processed
# 			Progress: 17/300 samples processed
# 			Progress: 18/300 samples processed
# 			Progress: 19/300 samples processed
# 			Progress: 20/300 samples processed
# 			Progress: 21/300 samples processed
# 			Progress: 22/300 samples processed
# 			Progress: 23/300 samples processed
# 			Progress: 24/300 samples processed
# 			Progress: 25/300 samples processed
# 			Progress: 26/300 samples processed
# 			Progress: 27/300 samples processed
# 			Progress: 28/300 samples processed
# 			Progress: 29/300 samples processed
# 			Progress: 30/300 samples processed
# 			Progress: 31/300 samples processed
# 			Progress: 32/300 samples processed
# 			Progress: 33/300 samples processed
# 			Progress: 34/300 samples processed
# 			Progress: 35/300 samples processed
# 			Progress: 36/300 samples processed
# 			Progress: 37/300 samples processed
# 			Progress: 38/300 samples processed
# 			Progress: 39/300 samples processed
# 			Progress: 40/300 samples processed
# 			Progress: 41/300 samples processed
# 			Progress: 42/300 samples processed
# 			Progress: 43/300 samples processed
# 			Progress: 44/300 samples processed
# 			Progress: 45/300 samples processed
# 			Progress: 46/300 samples processed
# 			Progress: 47/300 samples processed
# 			Progress: 48/300 samples processed
# 			Progress: 49/300 samples processed
# 			Progress: 50/300 samples processed
# 			Progress: 51/300 samples processed
# 			Progress: 52/300 samples processed
# 			Progress: 53/300 samples processed
# 			Progress: 54/300 samples processed
# 			Progress: 55/300 samples processed
# 			Progress: 56/300 samples processed
# 			Progress: 57/300 samples processed
# 			Progress: 58/300 samples processed
# 			Progress: 59/300 samples processed
# 			Progress: 60/300 samples processed
# 			Progress: 61/300 samples processed
# 			Progress: 62/300 samples processed
# 			Progress: 63/300 samples processed
# 			Progress: 64/300 samples processed
# 			Progress: 65/300 samples processed
# 			Progress: 66/300 samples processed
# 			Progress: 67/300 samples processed
# 			Progress: 68/300 samples processed
# 			Progress: 69/300 samples processed
# 			Progress: 70/300 samples processed
# 			Progress: 71/300 samples processed
# 			Progress: 72/300 samples processed
# 			Progress: 73/300 samples processed
# 			Progress: 74/300 samples processed
# 			Progress: 75/300 samples processed
# 			Progress: 76/300 samples processed
# 			Progress: 77/300 samples processed
# 			Progress: 78/300 samples processed
# 			Progress: 79/300 samples processed
# 			Progress: 80/300 samples processed
# 			Progress: 81/300 samples processed
# 			Progress: 82/300 samples processed
# 			Progress: 83/300 samples processed
# 			Progress: 84/300 samples processed
# 			Progress: 85/300 samples processed
# 			Progress: 86/300 samples processed
# 			Progress: 87/300 samples processed
# 			Progress: 88/300 samples processed
# 			Progress: 89/300 samples processed
# 			Progress: 90/300 samples processed
# 			Progress: 91/300 samples processed
# 			Progress: 92/300 samples processed
# 			Progress: 93/300 samples processed
# 			Progress: 94/300 samples processed
# 			Progress: 95/300 samples processed
# 			Progress: 96/300 samples processed
# 			Progress: 97/300 samples processed
# 			Progress: 98/300 samples processed
# 			Progress: 99/300 samples processed
# 			Progress: 100/300 samples processed
# 			Progress: 101/300 samples processed
# 			Progress: 102/300 samples processed
# 			Progress: 103/300 samples processed
# 			Progress: 104/300 samples processed
# 			Progress: 105/300 samples processed
# 			Progress: 106/300 samples processed
# 			Progress: 107/300 samples processed
# 			Progress: 108/300 samples processed
# 			Progress: 109/300 samples processed
# 			Progress: 110/300 samples processed
# 			Progress: 111/300 samples processed
# 			Progress: 112/300 samples processed
# 			Progress: 113/300 samples processed
# 			Progress: 114/300 samples processed
# 			Progress: 115/300 samples processed
# 			Progress: 116/300 samples processed
# 			Progress: 117/300 samples processed
# 			Progress: 118/300 samples processed
# 			Progress: 119/300 samples processed
# 			Progress: 120/300 samples processed
# 			Progress: 121/300 samples processed
# 			Progress: 122/300 samples processed
# 			Progress: 123/300 samples processed
# 			Progress: 124/300 samples processed
# 			Progress: 125/300 samples processed
# 			Progress: 126/300 samples processed
# 			Progress: 127/300 samples processed
# 			Progress: 128/300 samples processed
# 			Progress: 129/300 samples processed
# 			Progress: 130/300 samples processed
# 			Progress: 131/300 samples processed
# 			Progress: 132/300 samples processed
# 			Progress: 133/300 samples processed
# 			Progress: 134/300 samples processed
# 			Progress: 135/300 samples processed
# 			Progress: 136/300 samples processed
# 			Progress: 137/300 samples processed
# 			Progress: 138/300 samples processed
# 			Progress: 139/300 samples processed
# 			Progress: 140/300 samples processed
# 			Progress: 141/300 samples processed
# 			Progress: 142/300 samples processed
# 			Progress: 143/300 samples processed
# 			Progress: 144/300 samples processed
# 			Progress: 145/300 samples processed
# 			Progress: 146/300 samples processed
# 			Progress: 147/300 samples processed
# 			Progress: 148/300 samples processed
# 			Progress: 149/300 samples processed
# 			Progress: 150/300 samples processed
# 			Progress: 151/300 samples processed
# 			Progress: 152/300 samples processed
# 			Progress: 153/300 samples processed
# 			Progress: 154/300 samples processed
# 			Progress: 155/300 samples processed
# 			Progress: 156/300 samples processed
# 			Progress: 157/300 samples processed
# 			Progress: 158/300 samples processed
# 			Progress: 159/300 samples processed
# 			Progress: 160/300 samples processed
# 			Progress: 161/300 samples processed
# 			Progress: 162/300 samples processed
# 			Progress: 163/300 samples processed
# 			Progress: 164/300 samples processed
# 			Progress: 165/300 samples processed
# 			Progress: 166/300 samples processed
# 			Progress: 167/300 samples processed
# 			Progress: 168/300 samples processed
# 			Progress: 169/300 samples processed
# 			Progress: 170/300 samples processed
# 			Progress: 171/300 samples processed
# 			Progress: 172/300 samples processed
# 			Progress: 173/300 samples processed
# 			Progress: 174/300 samples processed
# 			Progress: 175/300 samples processed
# 			Progress: 176/300 samples processed
# 			Progress: 177/300 samples processed
# 			Progress: 178/300 samples processed
# 			Progress: 179/300 samples processed
# 			Progress: 180/300 samples processed
# 			Progress: 181/300 samples processed
# 			Progress: 182/300 samples processed
# 			Progress: 183/300 samples processed
# 			Progress: 184/300 samples processed
# 			Progress: 185/300 samples processed
# 			Progress: 186/300 samples processed
# 			Progress: 187/300 samples processed
# 			Progress: 188/300 samples processed
# 			Progress: 189/300 samples processed
# 			Progress: 190/300 samples processed
# 			Progress: 191/300 samples processed
# 			Progress: 192/300 samples processed
# 			Progress: 193/300 samples processed
# 			Progress: 194/300 samples processed
# 			Progress: 195/300 samples processed
# 			Progress: 196/300 samples processed
# 			Progress: 197/300 samples processed
# 			Progress: 198/300 samples processed
# 			Progress: 199/300 samples processed
# 			Progress: 200/300 samples processed
# 			Progress: 201/300 samples processed
# 			Progress: 202/300 samples processed
# 			Progress: 203/300 samples processed
# 			Progress: 204/300 samples processed
# 			Progress: 205/300 samples processed
# 			Progress: 206/300 samples processed
# 			Progress: 207/300 samples processed
# 			Progress: 208/300 samples processed
# 			Progress: 209/300 samples processed
# 			Progress: 210/300 samples processed
# 			Progress: 211/300 samples processed
# 			Progress: 212/300 samples processed
# 			Progress: 213/300 samples processed
# 			Progress: 214/300 samples processed
# 			Progress: 215/300 samples processed
# 			Progress: 216/300 samples processed
# 			Progress: 217/300 samples processed
# 			Progress: 218/300 samples processed
# 			Progress: 219/300 samples processed
# 			Progress: 220/300 samples processed
# 			Progress: 221/300 samples processed
# 			Progress: 222/300 samples processed
# 			Progress: 223/300 samples processed
# 			Progress: 224/300 samples processed
# 			Progress: 225/300 samples processed
# 			Progress: 226/300 samples processed
# 			Progress: 227/300 samples processed
# 			Progress: 228/300 samples processed
# 			Progress: 229/300 samples processed
# 			Progress: 230/300 samples processed
# 			Progress: 231/300 samples processed
# 			Progress: 232/300 samples processed
# 			Progress: 233/300 samples processed
# 			Progress: 234/300 samples processed
# 			Progress: 235/300 samples processed
# 			Progress: 236/300 samples processed
# 			Progress: 237/300 samples processed
# 			Progress: 238/300 samples processed
# 			Progress: 239/300 samples processed
# 			Progress: 240/300 samples processed
# 			Progress: 241/300 samples processed
# 			Progress: 242/300 samples processed
# 			Progress: 243/300 samples processed
# 			Progress: 244/300 samples processed
# 			Progress: 245/300 samples processed
# 			Progress: 246/300 samples processed
# 			Progress: 247/300 samples processed
# 			Progress: 248/300 samples processed
# 			Progress: 249/300 samples processed
# 			Progress: 250/300 samples processed
# 			Progress: 251/300 samples processed
# 			Progress: 252/300 samples processed
# 			Progress: 253/300 samples processed
# 			Progress: 254/300 samples processed
# 			Progress: 255/300 samples processed
# 			Progress: 256/300 samples processed
# 			Progress: 257/300 samples processed
# 			Progress: 258/300 samples processed
# 			Progress: 259/300 samples processed
# 			Progress: 260/300 samples processed
# 			Progress: 261/300 samples processed
# 			Progress: 262/300 samples processed
# 			Progress: 263/300 samples processed
# 			Progress: 264/300 samples processed
# 			Progress: 265/300 samples processed
# 			Progress: 266/300 samples processed
# 			Progress: 267/300 samples processed
# 			Progress: 268/300 samples processed
# 			Progress: 269/300 samples processed
# 			Progress: 270/300 samples processed
# 			Progress: 271/300 samples processed
# 			Progress: 272/300 samples processed
# 			Progress: 273/300 samples processed
# 			Progress: 274/300 samples processed
# 			Progress: 275/300 samples processed
# 			Progress: 276/300 samples processed
# 			Progress: 277/300 samples processed
# 			Progress: 278/300 samples processed
# 			Progress: 279/300 samples processed
# 			Progress: 280/300 samples processed
# 			Progress: 281/300 samples processed
# 			Progress: 282/300 samples processed
# 			Progress: 283/300 samples processed
# 			Progress: 284/300 samples processed
# 			Progress: 285/300 samples processed
# 			Progress: 286/300 samples processed
# 			Progress: 287/300 samples processed
# 			Progress: 288/300 samples processed
# 			Progress: 289/300 samples processed
# 			Progress: 290/300 samples processed
# 			Progress: 291/300 samples processed
# 			Progress: 292/300 samples processed
# 			Progress: 293/300 samples processed
# 			Progress: 294/300 samples processed
# 			Progress: 295/300 samples processed
# 			Progress: 296/300 samples processed
# 			Progress: 297/300 samples processed
# 			Progress: 298/300 samples processed
# 			Progress: 299/300 samples processed
# 			Progress: 300/300 samples processed
# Completed 4-shot testing for Mistral
#
# 	Testing with 6 shots...
# 			Progress: 1/300 samples processed
# 			Progress: 2/300 samples processed
# 			Progress: 3/300 samples processed
# 			Progress: 4/300 samples processed
# 			Progress: 5/300 samples processed
# 			Progress: 6/300 samples processed
# 			Progress: 7/300 samples processed
# 			Progress: 8/300 samples processed
# 			Progress: 9/300 samples processed
# 			Progress: 10/300 samples processed
# 			Progress: 11/300 samples processed
# 			Progress: 12/300 samples processed
# 			Progress: 13/300 samples processed
# 			Progress: 14/300 samples processed
# 			Progress: 15/300 samples processed
# 			Progress: 16/300 samples processed
# 			Progress: 17/300 samples processed
# 			Progress: 18/300 samples processed
# 			Progress: 19/300 samples processed
# 			Progress: 20/300 samples processed
# 			Progress: 21/300 samples processed
# 			Progress: 22/300 samples processed
# 			Progress: 23/300 samples processed
# 			Progress: 24/300 samples processed
# 			Progress: 25/300 samples processed
# 			Progress: 26/300 samples processed
# 			Progress: 27/300 samples processed
# 			Progress: 28/300 samples processed
# 			Progress: 29/300 samples processed
# 			Progress: 30/300 samples processed
# 			Progress: 31/300 samples processed
# 			Progress: 32/300 samples processed
# 			Progress: 33/300 samples processed
# 			Progress: 34/300 samples processed
# 			Progress: 35/300 samples processed
# 			Progress: 36/300 samples processed
# 			Progress: 37/300 samples processed
# 			Progress: 38/300 samples processed
# 			Progress: 39/300 samples processed
# 			Progress: 40/300 samples processed
# 			Progress: 41/300 samples processed
# 			Progress: 42/300 samples processed
# 			Progress: 43/300 samples processed
# 			Progress: 44/300 samples processed
# 			Progress: 45/300 samples processed
# 			Progress: 46/300 samples processed
# 			Progress: 47/300 samples processed
# 			Progress: 48/300 samples processed
# 			Progress: 49/300 samples processed
# 			Progress: 50/300 samples processed
# 			Progress: 51/300 samples processed
# 			Progress: 52/300 samples processed
# 			Progress: 53/300 samples processed
# 			Progress: 54/300 samples processed
# 			Progress: 55/300 samples processed
# 			Progress: 56/300 samples processed
# 			Progress: 57/300 samples processed
# 			Progress: 58/300 samples processed
# 			Progress: 59/300 samples processed
# 			Progress: 60/300 samples processed
# 			Progress: 61/300 samples processed
# 			Progress: 62/300 samples processed
# 			Progress: 63/300 samples processed
# 			Progress: 64/300 samples processed
# 			Progress: 65/300 samples processed
# 			Progress: 66/300 samples processed
# 			Progress: 67/300 samples processed
# 			Progress: 68/300 samples processed
# 			Progress: 69/300 samples processed
# 			Progress: 70/300 samples processed
# 			Progress: 71/300 samples processed
# 			Progress: 72/300 samples processed
# 			Progress: 73/300 samples processed
# 			Progress: 74/300 samples processed
# 			Progress: 75/300 samples processed
# 			Progress: 76/300 samples processed
# 			Progress: 77/300 samples processed
# 			Progress: 78/300 samples processed
# 			Progress: 79/300 samples processed
# 			Progress: 80/300 samples processed
# 			Progress: 81/300 samples processed
# 			Progress: 82/300 samples processed
# 			Progress: 83/300 samples processed
# 			Progress: 84/300 samples processed
# 			Progress: 85/300 samples processed
# 			Progress: 86/300 samples processed
# 			Progress: 87/300 samples processed
# 			Progress: 88/300 samples processed
# 			Progress: 89/300 samples processed
# 			Progress: 90/300 samples processed
# 			Progress: 91/300 samples processed
# 			Progress: 92/300 samples processed
# 			Progress: 93/300 samples processed
# 			Progress: 94/300 samples processed
# 			Progress: 95/300 samples processed
# 			Progress: 96/300 samples processed
# 			Progress: 97/300 samples processed
# 			Progress: 98/300 samples processed
# 			Progress: 99/300 samples processed
# 			Progress: 100/300 samples processed
# 			Progress: 101/300 samples processed
# 			Progress: 102/300 samples processed
# 			Progress: 103/300 samples processed
# 			Progress: 104/300 samples processed
# 			Progress: 105/300 samples processed
# 			Progress: 106/300 samples processed
# 			Progress: 107/300 samples processed
# 			Progress: 108/300 samples processed
# 			Progress: 109/300 samples processed
# 			Progress: 110/300 samples processed
# 			Progress: 111/300 samples processed
# 			Progress: 112/300 samples processed
# 			Progress: 113/300 samples processed
# 			Progress: 114/300 samples processed
# 			Progress: 115/300 samples processed
# 			Progress: 116/300 samples processed
# 			Progress: 117/300 samples processed
# 			Progress: 118/300 samples processed
# 			Progress: 119/300 samples processed
# 			Progress: 120/300 samples processed
# 			Progress: 121/300 samples processed
# 			Progress: 122/300 samples processed
# 			Progress: 123/300 samples processed
# 			Progress: 124/300 samples processed
# 			Progress: 125/300 samples processed
# 			Progress: 126/300 samples processed
# 			Progress: 127/300 samples processed
# 			Progress: 128/300 samples processed
# 			Progress: 129/300 samples processed
# 			Progress: 130/300 samples processed
# 			Progress: 131/300 samples processed
# 			Progress: 132/300 samples processed
# 			Progress: 133/300 samples processed
# 			Progress: 134/300 samples processed
# 			Progress: 135/300 samples processed
# 			Progress: 136/300 samples processed
# 			Progress: 137/300 samples processed
# 			Progress: 138/300 samples processed
# 			Progress: 139/300 samples processed
# 			Progress: 140/300 samples processed
# 			Progress: 141/300 samples processed
# 			Progress: 142/300 samples processed
# 			Progress: 143/300 samples processed
# 			Progress: 144/300 samples processed
# 			Progress: 145/300 samples processed
# 			Progress: 146/300 samples processed
# 			Progress: 147/300 samples processed
# 			Progress: 148/300 samples processed
# 			Progress: 149/300 samples processed
# 			Progress: 150/300 samples processed
# 			Progress: 151/300 samples processed
# 			Progress: 152/300 samples processed
# 			Progress: 153/300 samples processed
# 			Progress: 154/300 samples processed
# 			Progress: 155/300 samples processed
# 			Progress: 156/300 samples processed
# 			Progress: 157/300 samples processed
# 			Progress: 158/300 samples processed
# 			Progress: 159/300 samples processed
# 			Progress: 160/300 samples processed
# 			Progress: 161/300 samples processed
# 			Progress: 162/300 samples processed
# 			Progress: 163/300 samples processed
# 			Progress: 164/300 samples processed
# 			Progress: 165/300 samples processed
# 			Progress: 166/300 samples processed
# 			Progress: 167/300 samples processed
# 			Progress: 168/300 samples processed
# 			Progress: 169/300 samples processed
# 			Progress: 170/300 samples processed
# 			Progress: 171/300 samples processed
# 			Progress: 172/300 samples processed
# 			Progress: 173/300 samples processed
# 			Progress: 174/300 samples processed
# 			Progress: 175/300 samples processed
# 			Progress: 176/300 samples processed
# 			Progress: 177/300 samples processed
# 			Progress: 178/300 samples processed
# 			Progress: 179/300 samples processed
# 			Progress: 180/300 samples processed
# 			Progress: 181/300 samples processed
# 			Progress: 182/300 samples processed
# 			Progress: 183/300 samples processed
# 			Progress: 184/300 samples processed
# 			Progress: 185/300 samples processed
# 			Progress: 186/300 samples processed
# 			Progress: 187/300 samples processed
# 			Progress: 188/300 samples processed
# 			Progress: 189/300 samples processed
# 			Progress: 190/300 samples processed
# 			Progress: 191/300 samples processed
# 			Progress: 192/300 samples processed
# 			Progress: 193/300 samples processed
# 			Progress: 194/300 samples processed
# 			Progress: 195/300 samples processed
# 			Progress: 196/300 samples processed
# 			Progress: 197/300 samples processed
# 			Progress: 198/300 samples processed
# 			Progress: 199/300 samples processed
# 			Progress: 200/300 samples processed
# 			Progress: 201/300 samples processed
# 			Progress: 202/300 samples processed
# 			Progress: 203/300 samples processed
# 			Progress: 204/300 samples processed
# 			Progress: 205/300 samples processed
# 			Progress: 206/300 samples processed
# 			Progress: 207/300 samples processed
# 			Progress: 208/300 samples processed
# 			Progress: 209/300 samples processed
# 			Progress: 210/300 samples processed
# 			Progress: 211/300 samples processed
# 			Progress: 212/300 samples processed
# 			Progress: 213/300 samples processed
# 			Progress: 214/300 samples processed
# 			Progress: 215/300 samples processed
# 			Progress: 216/300 samples processed
# 			Progress: 217/300 samples processed
# 			Progress: 218/300 samples processed
# 			Progress: 219/300 samples processed
# 			Progress: 220/300 samples processed
# 			Progress: 221/300 samples processed
# 			Progress: 222/300 samples processed
# 			Progress: 223/300 samples processed
# 			Progress: 224/300 samples processed
# 			Progress: 225/300 samples processed
# 			Progress: 226/300 samples processed
# 			Progress: 227/300 samples processed
# 			Progress: 228/300 samples processed
# 			Progress: 229/300 samples processed
# 			Progress: 230/300 samples processed
# 			Progress: 231/300 samples processed
# 			Progress: 232/300 samples processed
# 			Progress: 233/300 samples processed
# 			Progress: 234/300 samples processed
# 			Progress: 235/300 samples processed
# 			Progress: 236/300 samples processed
# 			Progress: 237/300 samples processed
# 			Progress: 238/300 samples processed
# 			Progress: 239/300 samples processed
# 			Progress: 240/300 samples processed
# 			Progress: 241/300 samples processed
# 			Progress: 242/300 samples processed
# 			Progress: 243/300 samples processed
# 			Progress: 244/300 samples processed
# 			Progress: 245/300 samples processed
# 			Progress: 246/300 samples processed
# 			Progress: 247/300 samples processed
# 			Progress: 248/300 samples processed
# 			Progress: 249/300 samples processed
# 			Progress: 250/300 samples processed
# 			Progress: 251/300 samples processed
# 			Progress: 252/300 samples processed
# 			Progress: 253/300 samples processed
# 			Progress: 254/300 samples processed
# 			Progress: 255/300 samples processed
# 			Progress: 256/300 samples processed
# 			Progress: 257/300 samples processed
# 			Progress: 258/300 samples processed
# 			Progress: 259/300 samples processed
# 			Progress: 260/300 samples processed
# 			Progress: 261/300 samples processed
# 			Progress: 262/300 samples processed
# 			Progress: 263/300 samples processed
# 			Progress: 264/300 samples processed
# 			Progress: 265/300 samples processed
# 			Progress: 266/300 samples processed
# 			Progress: 267/300 samples processed
# 			Progress: 268/300 samples processed
# 			Progress: 269/300 samples processed
# 			Progress: 270/300 samples processed
# 			Progress: 271/300 samples processed
# 			Progress: 272/300 samples processed
# 			Progress: 273/300 samples processed
# 			Progress: 274/300 samples processed
# 			Progress: 275/300 samples processed
# 			Progress: 276/300 samples processed
# 			Progress: 277/300 samples processed
# 			Progress: 278/300 samples processed
# 			Progress: 279/300 samples processed
# 			Progress: 280/300 samples processed
# 			Progress: 281/300 samples processed
# 			Progress: 282/300 samples processed
# 			Progress: 283/300 samples processed
# 			Progress: 284/300 samples processed
# 			Progress: 285/300 samples processed
# 			Progress: 286/300 samples processed
# 			Progress: 287/300 samples processed
# 			Progress: 288/300 samples processed
# 			Progress: 289/300 samples processed
# 			Progress: 290/300 samples processed
# 			Progress: 291/300 samples processed
# 			Progress: 292/300 samples processed
# 			Progress: 293/300 samples processed
# 			Progress: 294/300 samples processed
# 			Progress: 295/300 samples processed
# 			Progress: 296/300 samples processed
# 			Progress: 297/300 samples processed
# 			Progress: 298/300 samples processed
# 			Progress: 299/300 samples processed
# 			Progress: 300/300 samples processed
# Completed 6-shot testing for Mistral
#
# 	Testing with 8 shots...
# 			Progress: 1/300 samples processed
# 			Progress: 2/300 samples processed
# 			Progress: 3/300 samples processed
# 			Progress: 4/300 samples processed
# 			Progress: 5/300 samples processed
# 			Progress: 6/300 samples processed
# 			Progress: 7/300 samples processed
# 			Progress: 8/300 samples processed
# 			Progress: 9/300 samples processed
# 			Progress: 10/300 samples processed
# 			Progress: 11/300 samples processed
# 			Progress: 12/300 samples processed
# 			Progress: 13/300 samples processed
# 			Progress: 14/300 samples processed
# 			Progress: 15/300 samples processed
# 			Progress: 16/300 samples processed
# 			Progress: 17/300 samples processed
# 			Progress: 18/300 samples processed
# 			Progress: 19/300 samples processed
# 			Progress: 20/300 samples processed
# 			Progress: 21/300 samples processed
# 			Progress: 22/300 samples processed
# 			Progress: 23/300 samples processed
# 			Progress: 24/300 samples processed
# 			Progress: 25/300 samples processed
# 			Progress: 26/300 samples processed
# 			Progress: 27/300 samples processed
# 			Progress: 28/300 samples processed
# 			Progress: 29/300 samples processed
# 			Progress: 30/300 samples processed
# 			Progress: 31/300 samples processed
# 			Progress: 32/300 samples processed
# 			Progress: 33/300 samples processed
# 			Progress: 34/300 samples processed
# 			Progress: 35/300 samples processed
# 			Progress: 36/300 samples processed
# 			Progress: 37/300 samples processed
# 			Progress: 38/300 samples processed
# 			Progress: 39/300 samples processed
# 			Progress: 40/300 samples processed
# 			Progress: 41/300 samples processed
# 			Progress: 42/300 samples processed
# 			Progress: 43/300 samples processed
# 			Progress: 44/300 samples processed
# 			Progress: 45/300 samples processed
# 			Progress: 46/300 samples processed
# 			Progress: 47/300 samples processed
# 			Progress: 48/300 samples processed
# 			Progress: 49/300 samples processed
# 			Progress: 50/300 samples processed
# 			Progress: 51/300 samples processed
# 			Progress: 52/300 samples processed
# 			Progress: 53/300 samples processed
# 			Progress: 54/300 samples processed
# 			Progress: 55/300 samples processed
# 			Progress: 56/300 samples processed
# 			Progress: 57/300 samples processed
# 			Progress: 58/300 samples processed
# 			Progress: 59/300 samples processed
# 			Progress: 60/300 samples processed
# 			Progress: 61/300 samples processed
# 			Progress: 62/300 samples processed
# 			Progress: 63/300 samples processed
# 			Progress: 64/300 samples processed
# 			Progress: 65/300 samples processed
# 			Progress: 66/300 samples processed
# 			Progress: 67/300 samples processed
# 			Progress: 68/300 samples processed
# 			Progress: 69/300 samples processed
# 			Progress: 70/300 samples processed
# 			Progress: 71/300 samples processed
# 			Progress: 72/300 samples processed
# 			Progress: 73/300 samples processed
# 			Progress: 74/300 samples processed
# 			Progress: 75/300 samples processed
# 			Progress: 76/300 samples processed
# 			Progress: 77/300 samples processed
# 			Progress: 78/300 samples processed
# 			Progress: 79/300 samples processed
# 			Progress: 80/300 samples processed
# 			Progress: 81/300 samples processed
# 			Progress: 82/300 samples processed
# 			Progress: 83/300 samples processed
# 			Progress: 84/300 samples processed
# 			Progress: 85/300 samples processed
# 			Progress: 86/300 samples processed
# 			Progress: 87/300 samples processed
# 			Progress: 88/300 samples processed
# 			Progress: 89/300 samples processed
# 			Progress: 90/300 samples processed
# 			Progress: 91/300 samples processed
# 			Progress: 92/300 samples processed
# 			Progress: 93/300 samples processed
# 			Progress: 94/300 samples processed
# 			Progress: 95/300 samples processed
# 			Progress: 96/300 samples processed
# 			Progress: 97/300 samples processed
# 			Progress: 98/300 samples processed
# 			Progress: 99/300 samples processed
# 			Progress: 100/300 samples processed
# 			Progress: 101/300 samples processed
# 			Progress: 102/300 samples processed
# 			Progress: 103/300 samples processed
# 			Progress: 104/300 samples processed
# 			Progress: 105/300 samples processed
# 			Progress: 106/300 samples processed
# 			Progress: 107/300 samples processed
# 			Progress: 108/300 samples processed
# 			Progress: 109/300 samples processed
# 			Progress: 110/300 samples processed
# 			Progress: 111/300 samples processed
# 			Progress: 112/300 samples processed
# 			Progress: 113/300 samples processed
# 			Progress: 114/300 samples processed
# 			Progress: 115/300 samples processed
# 			Progress: 116/300 samples processed
# 			Progress: 117/300 samples processed
# 			Progress: 118/300 samples processed
# 			Progress: 119/300 samples processed
# 			Progress: 120/300 samples processed
# 			Progress: 121/300 samples processed
# 			Progress: 122/300 samples processed
# 			Progress: 123/300 samples processed
# 			Progress: 124/300 samples processed
# 			Progress: 125/300 samples processed
# 			Progress: 126/300 samples processed
# 			Progress: 127/300 samples processed
# 			Progress: 128/300 samples processed
# 			Progress: 129/300 samples processed
# 			Progress: 130/300 samples processed
# 			Progress: 131/300 samples processed
# 			Progress: 132/300 samples processed
# 			Progress: 133/300 samples processed
# 			Progress: 134/300 samples processed
# 			Progress: 135/300 samples processed
# 			Progress: 136/300 samples processed
# 			Progress: 137/300 samples processed
# 			Progress: 138/300 samples processed
# 			Progress: 139/300 samples processed
# 			Progress: 140/300 samples processed
# 			Progress: 141/300 samples processed
# 			Progress: 142/300 samples processed
# 			Progress: 143/300 samples processed
# 			Progress: 144/300 samples processed
# 			Progress: 145/300 samples processed
# 			Progress: 146/300 samples processed
# 			Progress: 147/300 samples processed
# 			Progress: 148/300 samples processed
# 			Progress: 149/300 samples processed
# 			Progress: 150/300 samples processed
# 			Progress: 151/300 samples processed
# 			Progress: 152/300 samples processed
# 			Progress: 153/300 samples processed
# 			Progress: 154/300 samples processed
# 			Progress: 155/300 samples processed
# 			Progress: 156/300 samples processed
# 			Progress: 157/300 samples processed
# 			Progress: 158/300 samples processed
# 			Progress: 159/300 samples processed
# 			Progress: 160/300 samples processed
# 			Progress: 161/300 samples processed
# 			Progress: 162/300 samples processed
# 			Progress: 163/300 samples processed
# 			Progress: 164/300 samples processed
# 			Progress: 165/300 samples processed
# 			Progress: 166/300 samples processed
# 			Progress: 167/300 samples processed
# 			Progress: 168/300 samples processed
# 			Progress: 169/300 samples processed
# 			Progress: 170/300 samples processed
# 			Progress: 171/300 samples processed
# 			Progress: 172/300 samples processed
# 			Progress: 173/300 samples processed
# 			Progress: 174/300 samples processed
# 			Progress: 175/300 samples processed
# 			Progress: 176/300 samples processed
# 			Progress: 177/300 samples processed
# 			Progress: 178/300 samples processed
# 			Progress: 179/300 samples processed
# 			Progress: 180/300 samples processed
# 			Progress: 181/300 samples processed
# 			Progress: 182/300 samples processed
# 			Progress: 183/300 samples processed
# 			Progress: 184/300 samples processed
# 			Progress: 185/300 samples processed
# 			Progress: 186/300 samples processed
# 			Progress: 187/300 samples processed
# 			Progress: 188/300 samples processed
# 			Progress: 189/300 samples processed
# 			Progress: 190/300 samples processed
# 			Progress: 191/300 samples processed
# 			Progress: 192/300 samples processed
# 			Progress: 193/300 samples processed
# 			Progress: 194/300 samples processed
# 			Progress: 195/300 samples processed
# 			Progress: 196/300 samples processed
# 			Progress: 197/300 samples processed
# 			Progress: 198/300 samples processed
# 			Progress: 199/300 samples processed
# 			Progress: 200/300 samples processed
# 			Progress: 201/300 samples processed
# 			Progress: 202/300 samples processed
# 			Progress: 203/300 samples processed
# 			Progress: 204/300 samples processed
# 			Progress: 205/300 samples processed
# 			Progress: 206/300 samples processed
# 			Progress: 207/300 samples processed
# 			Progress: 208/300 samples processed
# 			Progress: 209/300 samples processed
# 			Progress: 210/300 samples processed
# 			Progress: 211/300 samples processed
# 			Progress: 212/300 samples processed
# 			Progress: 213/300 samples processed
# 			Progress: 214/300 samples processed
# 			Progress: 215/300 samples processed
# 			Progress: 216/300 samples processed
# 			Progress: 217/300 samples processed
# 			Progress: 218/300 samples processed
# 			Progress: 219/300 samples processed
# 			Progress: 220/300 samples processed
# 			Progress: 221/300 samples processed
# 			Progress: 222/300 samples processed
# 			Progress: 223/300 samples processed
# 			Progress: 224/300 samples processed
# 			Progress: 225/300 samples processed
# 			Progress: 226/300 samples processed
# 			Progress: 227/300 samples processed
# 			Progress: 228/300 samples processed
# 			Progress: 229/300 samples processed
# 			Progress: 230/300 samples processed
# 			Progress: 231/300 samples processed
# 			Progress: 232/300 samples processed
# 			Progress: 233/300 samples processed
# 			Progress: 234/300 samples processed
# 			Progress: 235/300 samples processed
# 			Progress: 236/300 samples processed
# 			Progress: 237/300 samples processed
# 			Progress: 238/300 samples processed
# 			Progress: 239/300 samples processed
# 			Progress: 240/300 samples processed
# 			Progress: 241/300 samples processed
# 			Progress: 242/300 samples processed
# 			Progress: 243/300 samples processed
# 			Progress: 244/300 samples processed
# 			Progress: 245/300 samples processed
# 			Progress: 246/300 samples processed
# 			Progress: 247/300 samples processed
# 			Progress: 248/300 samples processed
# 			Progress: 249/300 samples processed
# 			Progress: 250/300 samples processed
# 			Progress: 251/300 samples processed
# 			Progress: 252/300 samples processed
# 			Progress: 253/300 samples processed
# 			Progress: 254/300 samples processed
# 			Progress: 255/300 samples processed
# 			Progress: 256/300 samples processed
# 			Progress: 257/300 samples processed
# 			Progress: 258/300 samples processed
# 			Progress: 259/300 samples processed
# 			Progress: 260/300 samples processed
# 			Progress: 261/300 samples processed
# 			Progress: 262/300 samples processed
# 			Progress: 263/300 samples processed
# 			Progress: 264/300 samples processed
# 			Progress: 265/300 samples processed
# 			Progress: 266/300 samples processed
# 			Progress: 267/300 samples processed
# 			Progress: 268/300 samples processed
# 			Progress: 269/300 samples processed
# 			Progress: 270/300 samples processed
# 			Progress: 271/300 samples processed
# 			Progress: 272/300 samples processed
# 			Progress: 273/300 samples processed
# 			Progress: 274/300 samples processed
# 			Progress: 275/300 samples processed
# 			Progress: 276/300 samples processed
# 			Progress: 277/300 samples processed
# 			Progress: 278/300 samples processed
# 			Progress: 279/300 samples processed
# 			Progress: 280/300 samples processed
# 			Progress: 281/300 samples processed
# 			Progress: 282/300 samples processed
# 			Progress: 283/300 samples processed
# 			Progress: 284/300 samples processed
# 			Progress: 285/300 samples processed
# 			Progress: 286/300 samples processed
# 			Progress: 287/300 samples processed
# 			Progress: 288/300 samples processed
# 			Progress: 289/300 samples processed
# 			Progress: 290/300 samples processed
# 			Progress: 291/300 samples processed
# 			Progress: 292/300 samples processed

# %%
# Save results after each shot count test
for n_shots in shot_counts:
    results = test_n_shot_samples(model, tokenizer, test_df, demonstrations, n_shots, test_samples)
    save_model_results(results, model_name, n_shots)

# %% [markdown]
# # [Task 6] Error Analysis

# %% [markdown]
# # [Task 7] Report
